# %%
import sqlite3
from typing import List, Optional


class WikiMapper:
    """Uses a precomputed database created by `create_wikipedia_wikidata_mapping_db`."""

    def __init__(self, path_to_db: str):
        self._path_to_db = path_to_db
        self.conn = sqlite3.connect(self._path_to_db)

    def title_to_id(self, page_title: str) -> Optional[str]:
        """Given a Wikipedia page title, returns the corresponding Wikidata ID.
        The page title is the last part of a Wikipedia url **unescaped** and spaces
        replaced by underscores , e.g. for `https://en.wikipedia.org/wiki/Fermat%27s_Last_Theorem`,
        the title would be `Fermat's_Last_Theorem`.
        Args:
            page_title: The page title of the Wikipedia entry, e.g. `Manatee`.
        Returns:
            Optional[str]: If a mapping could be found for `wiki_page_title`, then return
                           it, else return `None`.
        """

        c = self.conn.execute("SELECT wikidata_id FROM mapping WHERE wikipedia_title=?", (page_title,))
        result = c.fetchone()

        if result is not None and result[0] is not None:
            return result[0]
        else:
            return None

    def url_to_id(self, wiki_url: str) -> Optional[str]:
        """Given an URL to a Wikipedia page, returns the corresponding Wikidata ID.
        This is just a convenience function. It is not checked whether the index and
        URL are from the same dump.
        Args:
            wiki_url: The URL to a Wikipedia entry.
        Returns:
            Optional[str]: If a mapping could be found for `wiki_url`, then return
                           it, else return `None`.
        """

        title = wiki_url.rsplit("/", 1)[-1]
        return self.title_to_id(title)

    def id_to_titles(self, wikidata_id: str) -> List[str]:
        """Given a Wikidata ID, return a list of corresponding pages that are linked to it.
        Due to redirects, the mapping from Wikidata ID to Wikipedia title is not unique.
        Args:
            wikidata_id (str): The Wikidata ID to map, e.g. `Q42797`.
        Returns:
            List[str]: A list of Wikipedia pages that are linked to this Wikidata ID.
        """

        c = self.conn.execute(
            "SELECT DISTINCT wikipedia_title FROM mapping WHERE wikidata_id =?", (wikidata_id,)
        )
        results = c.fetchall()

        return [e[0] for e in results]

map = WikiMapper('/Users/lucyhorowitz/Documents/MathGloss/wikidata/index_enwiki-20190420.db')

# %%
import csv
import requests

wikicats = ['_(mathematics)', '_(category_theory)', '_(linear_algebra)', '_(algebraic_geometry)', '_(algebraic_topology)',
             '_(commutative_algebra)', '_(field_theory)', '_(game_theory)', '_(topology)', '_(differential_geometry)', '_(graph_theory)', 
             '_(group_theory)', '_(invariant_theory)', '_(module_theory)', '_(order_theory)', '_(ring_theory)',
             '_(representation_theory)', '_(set_theory)', '_(string_theory)', '_(symplectic geometry)', '_(tensor_theory)']


            # Function to check if a title is a disambiguation page
def is_disambiguation_page(wikidata_id):
    url = f"https://www.wikidata.org/w/api.php"
    params = {
        "action": "wbgetentities",
        "ids": wikidata_id,
        "format": "json"
    }
    response = requests.get(url, params=params).json()
    claims = response.get("entities", {}).get(wikidata_id, {}).get("claims", {})
    if "P31" in claims:
        for claim in claims["P31"]:
            if claim.get("mainsnak", {}).get("datavalue", {}).get("value", {}).get("id") == "Q4167410":
                return True
    return False

# %% [markdown]
# # context

# %%
import os


# Define the folder containing the files
folder_path = 'context'

# Open the context_mappings.csv file to write the results
with open('context_mappings.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Wikidata ID', 'Context'])

    # Iterate over each file in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith('.md'):  # Assuming the files are markdown files
            with open(os.path.join(folder_path, filename), 'r') as f:
                for line in f:
                    if line.startswith('SUGGESTION'):
                        suggestion = line.split(':', 1)[1].strip().replace(' ', '_').capitalize()  # Read the suggestion line and format
                        break
            found = False
            for cat in wikicats:
                suggestion_with_cat = suggestion + cat
                wikidata_id = map.title_to_id(suggestion_with_cat)
                if wikidata_id and not is_disambiguation_page(wikidata_id):
                    writer.writerow([f"[{wikidata_id}](https://www.wikidata.org/wiki/{wikidata_id})", f"[{filename}](https://mathgloss.github.io/MathGloss/context/{filename})"])
                    print(f"SUGGCAT {suggestion_with_cat} found: {wikidata_id}")
                    found = True
                    break
            if not found:
                wikidata_id = map.title_to_id(suggestion)
                if wikidata_id and not is_disambiguation_page(wikidata_id):
                    writer.writerow([f"[{wikidata_id}](https://www.wikidata.org/wiki/{wikidata_id})", f"[{filename}](https://mathgloss.github.io/MathGloss/context/{filename})"])
                    print(f"SUGG {suggestion} found: {wikidata_id}")
                    found = True
                else:    
                    title = filename.replace('.md','').replace(' ', '_').capitalize()
                    for cat in wikicats:
                        title_with_cat = title + cat
                        wikidata_id = map.title_to_id(title_with_cat)
                        if wikidata_id and not is_disambiguation_page(wikidata_id):
                            writer.writerow([f"[{wikidata_id}](https://www.wikidata.org/wiki/{wikidata_id})", f"[{filename}](https://mathgloss.github.io/MathGloss/context/{filename})"])
                            print(f"REGCAT {suggestion_with_cat} found: {wikidata_id}")
                            found = True
                            break
                    if not found:
                        wikidata_id = map.title_to_id(title)
                        if wikidata_id and not is_disambiguation_page(wikidata_id):
                            writer.writerow([f"[{wikidata_id}](https://www.wikidata.org/wiki/{wikidata_id})", f"[{filename}](https://mathgloss.github.io/MathGloss/context/{filename})"])
                            print(f"REG {title} found: {wikidata_id}")
                            found = True
        if not found:
            print(f"NOT FOUND {filename}")
# Out:
# SUGG Simplicial_set found: Q1467124
# SUGG Full_subcategory found: Q541563
# NOT FOUND satisfied_by.md
# SUGG Split_epimorphism found: Q17103180
# SUGG Cocomplete_category found: Q4370335
# SUGG G-torsor found: Q3755543
# REG Effective found: Q1296024
# NOT FOUND space_of_configurations_of_n_points.md
# SUGG List_monad found: Q27948
# SUGGCAT Kernel_(category_theory) found: Q2920416
# SUGGCAT Coproduct_(category_theory) found: Q692689
# REGCAT Multiplication_natural_transformation_(tensor_theory) found: Q40276
# SUGGCAT Cokernel_(category_theory) found: Q2156511
# SUGG Fiber_space found: Q5446381
# SUGG Small_category found: Q719395
# SUGG Initial_object found: Q529752
# SUGGCAT Lattice_(group_theory) found: Q6497088
# NOT FOUND strictly_creates.md
# NOT FOUND right_inverse.md
# SUGG Sierpinski_space found: Q2119470
# NOT FOUND limit_cone.md
# SUGG Kernel_operator found: Q10564851
# NOT FOUND continuation_monads.md
# SUGG Unital_ring found: Q161172
# SUGGCAT Sheaf_(mathematics) found: Q595298
# REGCAT Unit_natural_transformation_(tensor_theory) found: Q118084
# SUGG Orbit-stabilizer_theorem found: Q288465
# NOT FOUND free_group_monad.md
# REG Summit found: Q207326
# SUGG Grothendieck_topos found: Q2143621
# NOT FOUND contravariant_Yoneda_embeddings.md
# NOT FOUND translation_groupoid.md
# SUGG Commutative_diagram found: Q621542
# SUGG Forgetful_functor found: Q2646117
# REG Shape found: Q207961
# NOT FOUND G-representation.md
# SUGG Strong_limit_cardinal found: Q1771501
# SUGGCAT Product_(mathematics) found: Q901718
# NOT FOUND solution_set_condition.md
# SUGG Direct_limit found: Q906015
# SUGG Complete_category found: Q4370335
# SUGGCAT Adjunction_(category_theory) found: Q357858
# SUGGCAT Coproduct_(category_theory) found: Q692689
# NOT FOUND right_closures.md
# NOT FOUND composite_morphism.md
# SUGG Monomorphism found: Q1945067
# SUGGCAT Lattice_(group_theory) found: Q6497088
# SUGG 2-category found: Q4596935
# NOT FOUND mutually_right_adjoint.md
# SUGG Poset found: Q474715
# SUGGCAT Morphism_(category_theory) found: Q1948412
# SUGGCAT Groupoid_(category_theory) found: Q1196038
# SUGG Constant_functor found: Q864475
# REG Pointwise found: Q9248237
# REGCAT Cone_under_a_small_category_(tensor_theory) found: Q42344
# NOT FOUND left_deformation.md
# SUGG Subfunctor found: Q7631142
# SUGG Natural_transformation found: Q1442189
# REGCAT Cofree_space_(tensor_theory) found: Q1503423
# SUGG Split_monomorphism found: Q17103180
# SUGG Commutative_square found: Q621542
# SUGG Kernel_pair found: Q2844249
# NOT FOUND right_deformation.md
# REGCAT Presentation_of_an_abelian_group_(tensor_theory) found: Q915906
# SUGG Initial_object found: Q529752
# NOT FOUND dependent_sum.md
# NOT FOUND compactly_generated_Hausdorff_spaces.md
# NOT FOUND absolute_Kan_extensions.md
# SUGG Riesz_representation_theorem found: Q1357684
# NOT FOUND universal_discrete_dynamical_system.md
# SUGG Full_functor found: Q1064276
# NOT FOUND reflects.md
# SUGGCAT Weak_equivalence_(mathematics) found: Q17104639
# NOT FOUND based_objects.md
# SUGG Representable_functor found: Q386320
# SUGG Separating_set found: Q7451799
# SUGG Inverse_limit found: Q2634828
# NOT FOUND weakly_initial.md
# NOT FOUND generators.md
# NOT FOUND cycles.md
# NOT FOUND model.md
# REG Truncation found: Q1080547
# NOT FOUND free.md
# SUGG Reflective_subcategory found: Q6101219
# SUGG Isomorphism_of_categories found: Q6086107
# SUGG Coinduction found: Q4227156
# SUGG Functor_category found: Q2007878
# SUGG Natural_transformation found: Q1442189
# SUGG Split_idempotent found: Q3055409
# SUGG Axiom found: Q17736
# SUGG Abstract_nonsense found: Q1084766
# NOT FOUND horizontal_composition.md
# NOT FOUND discrete_left_fibration.md
# SUGG Category_of_elements found: Q5051844
# SUGG Exact_functor found: Q381725
# NOT FOUND free_group_on_a_single_generator.md
# REG Lim_inf found: Q1076611
# NOT FOUND absolute_colimit.md
# SUGG Sheafification found: Q5572389
# NOT FOUND free_$T$-algebra.md
# SUGGCAT Pullback_(category_theory) found: Q1397439
# SUGG Jacobian_matrix found: Q506041
# NOT FOUND torsion-free.md
# SUGG Identity_morphism found: Q1948412
# SUGG Isomorphism found: Q189112
# NOT FOUND whiskering.md
# SUGG Inaccessible_cardinal found: Q1331373
# NOT FOUND morphism_of_adjunctions.md
# SUGG Nerve_of_a_category found: Q17099363
# SUGG Equivalence_of_categories found: Q1082992
# NOT FOUND total_singular_complex_functor.md
# NOT FOUND two-variable_adjunction.md
# SUGG Meet_semilattice found: Q834585
# NOT FOUND functoriality_axioms.md
# SUGG Free_loop_space found: Q2015432
# REG Preserves found: Q1269
# SUGG Automorphism_group found: Q60790315
# SUGG Propositional_function found: Q3606768
# SUGGCAT Equalizer_(mathematics) found: Q1224487
# SUGG Coequalizer found: Q5140810
# NOT FOUND category_of_$T$-algebras.md
# NOT FOUND indexing_category.md
# SUGG Abelian_category found: Q318737
# NOT FOUND commutative_rectangle.md
# SUGG Measurable_space found: Q3058218
# NOT FOUND adjunct.md
# SUGG Free_category found: Q5500202
# SUGGCAT Homeomorphism_(graph_theory) found: Q584521
# SUGG Torsion_subgroup found: Q2293759
# NOT FOUND coseparating_set.md
# SUGG Covariant_functor found: Q864475
# NOT FOUND creates_coequalizers_of_$U$-split_pairs.md
# NOT FOUND coYoneda_lemma.md
# SUGG Image_of_a_morphism found: Q860530
# NOT FOUND path_components_functor.md
# SUGG Terminal_object found: Q529752
# NOT FOUND universal_vector_space_equipped_with_a_bilinear_map.md
# REG Chain_complex found: Q1143328
# SUGG Slice_category found: Q1780005
# SUGGCAT Density_theorem_(category_theory) found: Q48996306
# NOT FOUND creates_isomorphisms.md
# SUGG Additive_functor found: Q2099981
# NOT FOUND representably_isomorphic.md
# NOT FOUND walking_arrow.md
# SUGGCAT Preorder_(mathematics) found: Q1425985
# SUGG Representable_functor found: Q386320
# SUGG Monadic_adjunction found: Q1630568
# SUGG Cayley's_theorem found: Q179208
# SUGG Contravariant_functor found: Q864475
# NOT FOUND jointly_weakly_initial.md
# SUGGCAT Path_(topology) found: Q1366002
# SUGG Slice_category found: Q1780005
# SUGG Left_exact_functor found: Q381725
# SUGG Function_space found: Q934367
# NOT FOUND walking_isomorphism.md
# SUGGCAT Sheaf_(mathematics) found: Q595298
# NOT FOUND re-parameterizations.md
# NOT FOUND path_components.md
# SUGGCAT Affine_space_(algebraic_geometry) found: Q382698
# NOT FOUND essentially_small.md
# NOT FOUND space_of_ordered_configurations_of_n_points.md
# SUGG Finest_topology found: Q906456
# SUGGCAT Fiber_(mathematics) found: Q1640811
# NOT FOUND coproduct_injections.md
# SUGG Join_semilattice found: Q834585
# SUGG Group_object found: Q765994
# SUGG Currying found: Q1144925
# SUGG Right_exact_functor found: Q381725
# REG Homomorphisms found: Q215111
# NOT FOUND discrete_right_fibration.md
# REGCAT Stabilizer_group_(tensor_theory) found: Q288465
# SUGG Locally_presentable_category found: Q4672496
# SUGG Accessible_functor found: Q4672496
# NOT FOUND essential_image.md
# SUGGCAT Category_(mathematics) found: Q719395
# NOT FOUND disjoint.md
# SUGG Closure_operator found: Q10564851
# SUGG Small_category found: Q719395
# NOT FOUND free_vector_space_monad.md
# SUGGCAT Monoid_(category_theory) found: Q2785361
# NOT FOUND -adic_integers.md
# REG Nadir found: Q145825
# REGCAT Universal_colimit_cone_(tensor_theory) found: Q1417809
# SUGG Concrete_category found: Q1575634
# SUGG Natural_transformation found: Q1442189
# SUGG Closed_subset found: Q320357
# SUGG Universal_element found: Q386320
# SUGG Zariski_topology found: Q147978
# NOT FOUND free_arrow.md
# SUGG Abelianization found: Q522216
# NOT FOUND convenient_category_of_topological_spaces.md
# NOT FOUND free_T-algebra_morphism.md
# SUGG Monadic_adjunction found: Q1630568
# SUGG Extension_of_scalars found: Q16858946
# SUGG Locally_small_category found: Q719395
# NOT FOUND bipointed_space.md
# NOT FOUND left_inverse.md
# NOT FOUND category_of_models_for_an_algebraic_theory.md
# REG Structures found: Q6671777
# NOT FOUND representable_isomorphism.md
# NOT FOUND lower_adjoint.md
# NOT FOUND Stone--vC.md
# REGCAT Transitive_left_g-set_(tensor_theory) found: Q671944
# SUGG Evaluation_map found: Q13416298
# SUGG T-algebra found: Q1630568
# SUGG Triangle_identities found: Q8084
# NOT FOUND point-set_left_derived_functor.md
# SUGGCAT Continuous_function_(topology) found: Q170058
# SUGG Closure_operator found: Q10564851
# SUGGCAT Cone_(mathematics) found: Q42344
# SUGG Unit_object found: Q1945014
# NOT FOUND ification.md
# SUGG Fundamental_theorem_of_galois_theory found: Q766522
# NOT FOUND essentially_discrete.md
# NOT FOUND transposes.md
# NOT FOUND total_right_derived_functor.md
# REGCAT Counit_of_the_adjunction_(tensor_theory) found: Q357858
# REG Lim_sup found: Q1076611
# SUGGCAT Retraction_(category_theory) found: Q17103180
# NOT FOUND loops_vdash_suspension_adjunction.md
# NOT FOUND G-space.md
# SUGGCAT Continuity_(mathematics) found: Q5165409
# NOT FOUND terminal_coalgebra.md
# SUGG Group_ring found: Q2602722
# SUGG Automorphism found: Q782566
# SUGGCAT Signature_(topology) found: Q7512811
# SUGG Symmetric_monoidal_category found: Q17103860
# SUGG Universal_coefficient_theorem found: Q2495664
# REG Double_dual found: Q752487
# SUGG Coarsest_topology found: Q906456
# NOT FOUND free_isomorphism.md
# SUGG Equivalence_relation found: Q130998
# NOT FOUND free_R-module_on_a_single_generator.md
# REGCAT Intersection_of_subobjects_(tensor_theory) found: Q17141489
# SUGG Bifunctor found: Q864475
# REGCAT Atomic_arrow_(tensor_theory) found: Q261484
# REG Homotopical found: Q746083
# SUGGCAT Groupoid_(category_theory) found: Q1196038
# NOT FOUND codensity\footnote{A_functor_$G_\colon_\cD_\to_\cC$_is_\textbf{codense.md
# SUGG Natural_transformation found: Q1442189
# NOT FOUND right_Kan_extension.md
# SUGGCAT Category_(mathematics) found: Q719395
# NOT FOUND constant_natural_transformation.md
# NOT FOUND homotopical_category.md
# SUGG Fully_faithful_functor found: Q1064276
# SUGGCAT Monad_(category_theory) found: Q1630568
# SUGG Hilbert's_nullstellensatz found: Q1068976
# NOT FOUND image_factorization.md
# SUGG Hom-set found: Q1948412
# NOT FOUND creates.md
# SUGG Group_extension found: Q3041173
# NOT FOUND copowers.md
# SUGGCAT Diagram_(category_theory) found: Q843237
# SUGG Homology_functor found: Q1095056
# SUGG Left_action found: Q288465
# REGCAT Kernel_of_a_map_(tensor_theory) found: Q2920416
# REG Species found: Q7432
# REGCAT Equalizer_morphism_(tensor_theory) found: Q1224487
# NOT FOUND (product)_projections.md
# NOT FOUND pointwise_left_Kan_extension.md
# NOT FOUND generalized_element.md
# SUGG Ultrafilter found: Q1571831
# SUGGCAT Colimit_(category_theory) found: Q1322614
# SUGG Cartesian_closed_category found: Q1725874
# SUGG Filtered_category found: Q5449247
# NOT FOUND orbit_category.md
# SUGG Left_derived_functor found: Q320245
# NOT FOUND tensor_product_bifunctor.md
# SUGG Tensor_product found: Q1163016
# NOT FOUND Eilenberg--Moore_category.md
# SUGG Unit_interval found: Q1987578
# SUGGCAT Coalgebra_(category_theory) found: Q3062935
# NOT FOUND point-set_right_derived_functor.md
# SUGG Arrows found: Q45922
# SUGG Comonad found: Q1630568
# SUGG Connected_category found: Q5161408
# SUGGCAT Embedding_(field_theory) found: Q980509
# SUGG Terminal_object found: Q529752
# SUGG 2-functor found: Q25304059
# SUGG Monoidal_category found: Q1945014
# REG Domain_of_definition found: Q192439
# NOT FOUND augmented_simplicial_sets.md
# NOT FOUND homotopy_category_of_spaces.md
# REG Cardinality found: Q4049983
# NOT FOUND upper_adjoint.md
# NOT FOUND functors_represented_by.md
# NOT FOUND labeled_F-structures.md
# SUGG Induction_functor found: Q3427423
# SUGG Maybe_monad found: Q1579914
# NOT FOUND left_Kan_extension.md
# SUGG Bilinear_map found: Q1086961
# NOT FOUND reflect_isomorphisms.md
# REGCAT Domain_morphism_(tensor_theory) found: Q192439
# NOT FOUND sequential_colimit.md
# SUGG Epic_morphism found: Q1347208
# SUGG Kernel_pair found: Q2844249
# SUGG Homotopy_category found: Q14775269
# NOT FOUND $U$-split_coequalizer.md
# REG Left_adjoint found: Q357858
# NOT FOUND middle_four_interchange.md
# NOT FOUND category_internal_to.md
# REG G-set found: Q288465
# NOT FOUND free_monoid_monad.md
# NOT FOUND models.md
# SUGG Left_derived_functor found: Q320245
# NOT FOUND fully-specified_adjunction.md
# SUGG Cocontinuous_functor found: Q1322614
# SUGG Endofunctor found: Q864475
# NOT FOUND G-equivariant.md
# SUGG Pullback_square found: Q1397439
# SUGG Symmetric_monoidal_category found: Q17103860
# NOT FOUND boundary_homomorphisms.md
# NOT FOUND monotone.md
# SUGG Discrete_dynamical_system found: Q378637
# NOT FOUND Eilenberg--MacLane_space.md
# SUGG Galois_connection found: Q1491747
# NOT FOUND representable_universal_property_of_the_limit.md
# SUGGCAT Codomain_(mathematics) found: Q199006
# SUGG Terminal_object found: Q529752
# NOT FOUND point-set_derived_functors.md
# SUGG Galois_extension found: Q2020004
# SUGGCAT Bijection_(mathematics) found: Q180907
# NOT FOUND total_left_derived_functor.md
# SUGG Symmetric_monoidal_category found: Q17103860
# SUGG Separating_set found: Q7451799
# SUGG Reduced_suspension found: Q1307987
# SUGGCAT Adjunction_(category_theory) found: Q357858
# NOT FOUND 2-of-6_property.md
# REG Geometric_realization found: Q1467124
# SUGGCAT Fixed_point_(mathematics) found: Q217608
# NOT FOUND pointwise_right_Kan_extension.md
# NOT FOUND locally_$\kappa$-presentable.md
# NOT FOUND affine_linear_combination.md
# SUGGCAT Sheaf_(mathematics) found: Q595298
# NOT FOUND double_dual_monad.md
# NOT FOUND representable_universal_property_of_the_colimit.md
# NOT FOUND opposing_pair.md
# SUGG Smash_product found: Q2295009
# SUGG Group_completion found: Q1128678
# SUGG Biproduct found: Q4915506
# SUGG Grothendieck_group found: Q1128678
# SUGG Regular_cardinal found: Q1193137
# SUGG Free_group found: Q431078
# SUGG Lawvere_theory found: Q6505076
# NOT FOUND limit_diagram.md
# NOT FOUND epi.md
# NOT FOUND under.md
# SUGG Directed_graph found: Q1137726
# SUGG Frobenius_reciprocity found: Q48998319
# NOT FOUND basepoint.md
# SUGGCAT Power_(mathematics) found: Q33456
# SUGG Reflective_subcategory found: Q6101219
# SUGGCAT Morphism_(category_theory) found: Q1948412
# SUGGCAT Cokernel_(category_theory) found: Q2156511
# SUGG Monomorphism found: Q1945067
# NOT FOUND philosophy_of_generalized_elements.md
# SUGG Weak_homotopy_equivalence found: Q17104639
# SUGG Commutator_subgroup found: Q522216
# SUGG Dual_basis found: Q2297777
# NOT FOUND mutually_left_adjoint.md
# SUGG Partial_function found: Q1756942
# NOT FOUND apex.md
# NOT FOUND dense_subcategory.md
# SUGG Conservative_functor found: Q23808682
# SUGGCAT Boundary_(topology) found: Q875399
# SUGG Quasi-isomorphism found: Q3413378
# REG Finitary found: Q5450381
# SUGG Galois_group found: Q730384
# SUGG Equivalence_relation found: Q130998
# NOT FOUND antitone_Galois_connection.md
# NOT FOUND weakly_initial_object.md
# NOT FOUND idempotent_monad.md
# SUGG Topological_monoid found: Q25098802
# NOT FOUND unlabeled_F-structures.md
# NOT FOUND finite.md
# SUGG Natural_isomorphism found: Q1442189
# NOT FOUND dependent_product.md
# SUGG Fundamental_groupoid found: Q662830
# REGCAT Monad_on_a_category_(tensor_theory) found: Q1630568
# SUGG Kleisli_category found: Q1773982
# SUGG Equivalence_of_categories found: Q1082992
# SUGG Dual_vector_space found: Q752487
# SUGG Decategorification found: Q5051825
# SUGG Comma_category found: Q1780005
# SUGG Subobject found: Q2547089
# NOT FOUND free_unital_ring_on_a_single_generator.md
# SUGG Idempotent_endomorphism found: Q2243424
# NOT FOUND affine.md
# SUGG Full_embedding found: Q541563
# NOT FOUND cone_over.md
# SUGG Discrete_category found: Q1228851
# REG Regular_cardinal found: Q1193137
# NOT FOUND dual_theorem.md
# SUGG Slice_category found: Q1780005
# SUGG Epimorphism found: Q1347208
# REGCAT Isomorphic_objects_(tensor_theory) found: Q189112
# SUGG Subcategory found: Q541563
# SUGG Skeletal_category found: Q2291918
# NOT FOUND free_R-module_monad.md
# NOT FOUND maximal_groupoid.md
# NOT FOUND contractible_groupoid.md
# NOT FOUND commutative_cube.md
# SUGG Equivalence_relation found: Q130998
# SUGGCAT Direct_sum_(topology) found: Q5282259
# SUGG Abelian_category found: Q318737
# NOT FOUND based_loop_space.md
# SUGG Free_product_of_groups found: Q1454165
# SUGG Natural_transformation found: Q1442189
# REGCAT **action**_(tensor_theory) found: Q288465
# SUGG Representable_functor found: Q386320
# SUGGCAT Orbit_(group_theory) found: Q288465
# NOT FOUND on_n_generators.md
# NOT FOUND center_of_the_category.md
# SUGG P-adic_solenoid found: Q3489713
# SUGG Opposite_category found: Q7098616
# NOT FOUND finite_formal_sum.md
# SUGGCAT Section_(category_theory) found: Q17103180
# SUGG Total_derivative found: Q636889
# REG Chaotic found: Q5072826
# SUGG P-adic_integer found: Q311627
# SUGG Categorification found: Q5051825
# REGCAT Limit_object_(tensor_theory) found: Q177239
# NOT FOUND localization_functor.md
# SUGG Free_abelian_group found: Q1454111
# NOT FOUND minimal_homotopical_structure.md
# SUGG Kleisli_category found: Q1773982
# SUGG Linear_functional found: Q261527
# NOT FOUND Giry_monad.md
# NOT FOUND coequalizer_diagram.md
# NOT FOUND classifying_function.md
# NOT FOUND joins.md
# NOT FOUND Beck--Chevalley_condition.md
# NOT FOUND linear_dual.md
# SUGG Free_vector_space found: Q1292333
# SUGG Initial_object found: Q529752
# NOT FOUND whiskered_composite.md
# SUGGCAT Equalizer_(mathematics) found: Q1224487
# NOT FOUND trivial_fiber_space.md
# NOT FOUND monadic_over.md
# NOT FOUND free_commutative_monoid_monad.md
# REGCAT Skeleton_of_a_category_(tensor_theory) found: Q2291918
# REGCAT Dense_subcategory_(tensor_theory) found: Q673444
# SUGG Exact_sequence found: Q1326955
# NOT FOUND strictly_monadic.md
# NOT FOUND terminal_n-colored_graph.md
# SUGG Restriction_of_scalars_functor found: Q7980190
# SUGGCAT Connected_component_(topology) found: Q1491995
# NOT FOUND two-sided_represented_functor.md
# SUGG Interior_of_a_set found: Q862761
# NOT FOUND colimit_diagram.md
# NOT FOUND reflexive.md
# SUGG Universal_element found: Q386320
# SUGGCAT Classifying_space_(category_theory) found: Q17099363
# SUGG Galois_connection found: Q1491747
# SUGG Center_of_a_group found: Q1195852
# NOT FOUND split_coequalizer.md
# SUGGCAT Pushout_(mathematics) found: Q1633079
# NOT FOUND vertical_composition.md
# SUGGCAT Reflector_(mathematics) found: Q426221
# SUGG Subobject_classifier found: Q7631737
# SUGGCAT Presheaf_(mathematics) found: Q595298
# SUGG Endomorphism found: Q1340800
# SUGGCAT Cone_(mathematics) found: Q42344
# SUGG Abelian_category found: Q318737
# SUGGCAT Functor_(category_theory) found: Q864475
# SUGGCAT Presentation_(group_theory) found: Q915906
# SUGGCAT Sheaf_(mathematics) found: Q595298
# SUGG Opposite_group found: Q3117899
# SUGG Faithful_functor found: Q1064276
# NOT FOUND strictly_creates_coequalizers_of_$U$-split_pairs.md
# NOT FOUND right_action.md
# SUGG Four_color_theorem found: Q184410
# NOT FOUND free_T-algebra.md
# SUGG Tensor found: Q188524
# SUGG Fork found: Q81881
# SUGG Complete_lattice found: Q2362924
# NOT FOUND double_power_set_monad.md
# SUGGCAT Retraction_(category_theory) found: Q17103180
# SUGG Monic_morphism found: Q1945067
# SUGG Absolute_coequalizer found: Q5140810
# NOT FOUND cotensors.md
# NOT FOUND cone_under.md
# NOT FOUND colimit_cone.md
# NOT FOUND reflexive_directed_graphs.md
# REGCAT Affine_algebra_(tensor_theory) found: Q3968
# NOT FOUND free_abelian_group_monad.md
# SUGG Essentially_surjective_functor found: Q140283
# SUGG Coskeleton found: Q5154570
# REG Right_adjoint found: Q357858
# NOT FOUND variable_adjunction.md
# SUGG Homotopy_equivalence found: Q746083
# REGCAT Terminal_coalgebra_(tensor_theory) found: Q3062935
# NOT FOUND twisted_arrow_category.md

# %%
print(map.title_to_id("Zorn's_lemma"))
# Out:
# Q290810

# %%
for cat in wikicats:
    suggestion_with_cat = "Simplicial_set" + cat
    
    if wikidata_id:
        print(f"Simplicial_set{cat}: {wikidata_id}")
    else:
        print(f"Simplicial_set{cat}: NOT FOUND")
# Out:
# Simplicial_set_(mathematics): NOT FOUND
# Simplicial_set_(category_theory): NOT FOUND
# Simplicial_set_(linear_algebra): NOT FOUND
# Simplicial_set_(algebraic_geometry): NOT FOUND
# Simplicial_set_(algebraic_topology)_(commutative_algebra): NOT FOUND
# Simplicial_set_(field_theory): NOT FOUND
# Simplicial_set_(game_theory): NOT FOUND
# Simplicial_set_(topology): NOT FOUND
# Simplicial_set_(differential_geometry): NOT FOUND
# Simplicial_set_(graph_theory): NOT FOUND
# Simplicial_set_(group_theory): NOT FOUND
# Simplicial_set_(invariant_theory): NOT FOUND
# Simplicial_set_(module_theory): NOT FOUND
# Simplicial_set_(order_theory): NOT FOUND
# Simplicial_set_(ring_theory): NOT FOUND
# Simplicial_set_(representation_theory): NOT FOUND
# Simplicial_set_(set_theory): NOT FOUND
# Simplicial_set_(string_theory): NOT FOUND
# Simplicial_set_(symplectic geometry): NOT FOUND
# Simplicial_set_(tensor_theory): NOT FOUND

# %% [markdown]
# # nlab

# %%
import urllib.parse
# Open the nlab_page_names_raw.txt file to read the lines
with open('/Users/lucyhorowitz/Documents/GitHub/MathGloss/nlab/nlab_page_names_raw.txt', 'r') as file:
    lines = file.readlines()

# Open the nlab_mappings.csv file to write the results
with open('nlab_mappings.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Wikidata ID', 'NLab Page'])

    # Iterate over each line in the file
    for line in lines:
        suggestion = line.strip().replace(' ', '_')
        suggestion = suggestion[0].upper() + suggestion[1:]  # Capitalize only the first character
        found = False
        for cat in wikicats:
            suggestion_with_cat = suggestion + cat
            wikidata_id = map.title_to_id(suggestion_with_cat)
            if wikidata_id and not is_disambiguation_page(wikidata_id):
                nlab_link = f"https://ncatlab.org/nlab/show/{urllib.parse.quote(line.strip().replace(' ', '+'))}"
                writer.writerow([f"[{wikidata_id}](https://www.wikidata.org/wiki/{wikidata_id})", nlab_link])
                print(f"SUGGCAT {suggestion_with_cat} found: {wikidata_id}")
                found = True
                break
        if not found:
            wikidata_id = map.title_to_id(suggestion)
            if wikidata_id and not is_disambiguation_page(wikidata_id):
                nlab_link = f"https://ncatlab.org/nlab/show/{urllib.parse.quote(line.strip().replace(' ', '+'))}"
                writer.writerow([f"[{wikidata_id}](https://www.wikidata.org/wiki/{wikidata_id})", nlab_link])
                print(f"SUGG {suggestion} found: {wikidata_id}")
                found = True
            else:    
                title = suggestion
                for cat in wikicats:
                    title_with_cat = title + cat
                    wikidata_id = map.title_to_id(title_with_cat)
                    if wikidata_id and not is_disambiguation_page(wikidata_id):
                        nlab_link = f"https://ncatlab.org/nlab/show/{urllib.parse.quote(line.strip().replace(' ', '+'))}"
                        writer.writerow([f"[{wikidata_id}](https://www.wikidata.org/wiki/{wikidata_id})", nlab_link])
                        print(f"REGCAT {title_with_cat} found: {wikidata_id}")
                        found = True
                        break
                if not found:
                    wikidata_id = map.title_to_id(title)
                    if wikidata_id and not is_disambiguation_page(wikidata_id):
                        nlab_link = f"https://ncatlab.org/nlab/show/{urllib.parse.quote(line.strip().replace(' ', '+'))}"
                        writer.writerow([f"[{wikidata_id}](https://www.wikidata.org/wiki/{wikidata_id})", nlab_link])
                        print(f"REG {title} found: {wikidata_id}")
                        found = True
        if not found:
            print(f"NOT FOUND {suggestion}")
# Out:
# NOT FOUND !-modality
# NOT FOUND $\infty$-category_>_history
# NOT FOUND $n$-category_>_history
# SUGG 't_Hooft_anomaly found: Q4769949
# NOT FOUND 't_Hooft_coupling
# NOT FOUND 't_Hooft_double_line_notation
# SUGG 't_Hooft-Polyakov_monopole found: Q8170996
# NOT FOUND (-1)-category
# NOT FOUND (-1)-functor
# NOT FOUND (-1)-groupoid
# NOT FOUND (-1)-poset
# NOT FOUND (-2)-category
# NOT FOUND (-2)-groupoid
# NOT FOUND (0,1)-category
# NOT FOUND (0,1)-category_theory
# NOT FOUND (0,1)-category_theory_-_contents
# NOT FOUND (0,1)-presheaf
# NOT FOUND (0,1)-topos
# NOT FOUND (1,0)-category
# NOT FOUND (1,1)-category
# NOT FOUND (1,1)-dimensional_Euclidean_field_theories_and_K-theory
# NOT FOUND (1,2)-topos
# NOT FOUND (2,1)-algebraic_theory_of_E-infinity_algebras
# NOT FOUND (2,1)-category
# NOT FOUND (2,1)-dimensional_Euclidean_field_theories_and_tmf
# NOT FOUND (2,1)-functor
# NOT FOUND (2,1)-presheaf
# NOT FOUND (2,1)-sheaf
# NOT FOUND (2,1)-sheafification
# NOT FOUND (2,1)-site
# NOT FOUND (2,1)-topos_of_(2,1)-sheaves
# NOT FOUND (2|1)-dimensional_Euclidean_field_theory
# NOT FOUND (bo,_ff)_factorization_system
# NOT FOUND (classical)_axiom_of_multiple_choice
# NOT FOUND (co)isotropic_subspaces_-_table
# NOT FOUND (d,d)_Klein_space
# NOT FOUND (dense,closed)-factorization
# NOT FOUND (epi,_mono)_factorization_system
# NOT FOUND (eso_and_full,_faithful)_factorization_system
# NOT FOUND (eso,_fully_faithful)_factorization_system
# NOT FOUND (g-2)_anomaly
# NOT FOUND (geometric_surjection,_embedding)_factorization_system
# NOT FOUND (hyperconnected,_localic)_factorization_system
# NOT FOUND (infinity,0)-category
# NOT FOUND (infinity,1)-bimodule
# NOT FOUND (infinity,1)-categorical_hom-space
# NOT FOUND (infinity,1)-categorification
# SUGG (infinity,1)-category found: Q7269442
# NOT FOUND (infinity,1)-category_>_history
# NOT FOUND (infinity,1)-category_of_(infinity,1)-categories
# NOT FOUND (infinity,1)-category_of_(infinity,1)-functors
# NOT FOUND (infinity,1)-category_of_(infinity,1)-presheaves
# NOT FOUND (infinity,1)-category_of_(infinity,1)-sheaves
# NOT FOUND (infinity,1)-category_of_cartesian_sections
# NOT FOUND (infinity,1)-category_of_chain_complexes
# NOT FOUND (infinity,1)-category_theory
# NOT FOUND (infinity,1)-functor
# NOT FOUND (infinity,1)-geometric_morphism
# NOT FOUND (infinity,1)-Grothendieck_construction
# NOT FOUND (infinity,1)-Kan_extension
# NOT FOUND (infinity,1)-module
# NOT FOUND (infinity,1)-module_bundle
# NOT FOUND (infinity,1)-monad
# NOT FOUND (infinity,1)-operad
# NOT FOUND (infinity,1)-presheaf
# NOT FOUND (infinity,1)-pretopos
# NOT FOUND (infinity,1)-profunctor
# NOT FOUND (infinity,1)-pullback
# NOT FOUND (infinity,1)-pushout
# NOT FOUND (infinity,1)-quantity
# NOT FOUND (infinity,1)-quasitopos
# NOT FOUND (infinity,1)-semitopos
# NOT FOUND (infinity,1)-sheaf
# NOT FOUND (infinity,1)-sheafification
# NOT FOUND (infinity,1)-site
# NOT FOUND (infinity,1)-topos
# NOT FOUND (infinity,1)-topos_-_contents
# NOT FOUND (infinity,1)-topos_theory
# NOT FOUND (infinity,1)-Yoneda_extension
# NOT FOUND (infinity,1)Cat
# NOT FOUND (infinity,1)Prof
# NOT FOUND (infinity,1)Topos
# NOT FOUND (infinity,2)-Categories_and_the_Goodwillie_Calculus
# NOT FOUND (infinity,2)-category
# NOT FOUND (infinity,2)-sheaf
# NOT FOUND (infinity,2)-site
# NOT FOUND (infinity,2)-topos
# NOT FOUND (infinity,2)-topos_theory_-_contents
# NOT FOUND (infinity,n)-category
# NOT FOUND (infinity,n)-category_of_cobordisms
# NOT FOUND (infinity,n)-category_of_correspondences
# NOT FOUND (infinity,n)-category_with_adjoints
# NOT FOUND (infinity,n)-category_with_duals
# NOT FOUND (infinity,n)-functor
# NOT FOUND (infinity,n)-module
# NOT FOUND (infinity,n)-natural_transformation
# NOT FOUND (infinity,n)-presheaf
# NOT FOUND (infinity,n)-sheaf
# NOT FOUND (infinity,n)-topos
# NOT FOUND (infinity,n)Cat
# NOT FOUND (infinity,r)-category_>_history
# NOT FOUND (n_×_k)-category
# NOT FOUND (n+1,1)-category_of_n-truncated_objects
# NOT FOUND (n,0)-category
# NOT FOUND (n,1)-category
# NOT FOUND (n,1)-sheaf
# NOT FOUND (n,1)-topos
# NOT FOUND (n,n)-category
# NOT FOUND (n,r)-category
# NOT FOUND (n,r)-congruence
# NOT FOUND (n,r)-site
# NOT FOUND (n-connected,_n-truncated)_factorization_system
# NOT FOUND (p,q)-string
# NOT FOUND (p,q)5-brane
# NOT FOUND (sub)object_classifier_in_an_(infinity,1)-topos
# NOT FOUND (∞%2C1)-category_>_history
# NOT FOUND (∞,0)-category_>_history
# NOT FOUND (∞,1)-algebra_over_an_(∞,1)-operad_>_history
# NOT FOUND (∞,1)-algebraic_theory
# NOT FOUND (∞,1)-category_of_(∞,1)-categories_>_history
# NOT FOUND (∞,1)-category_of_(∞,1)-modules
# NOT FOUND (∞,1)-comparison_lemma
# NOT FOUND (∞,1)-end
# NOT FOUND (∞,1)-limit
# NOT FOUND (∞,1)-local_geometric_morphism
# NOT FOUND (∞,1)-logic
# NOT FOUND (∞,1)Operad
# NOT FOUND (∞,2)-category_of_cobordisms
# NOT FOUND (∞,2)-category_theory
# NOT FOUND (∞,2)-functor
# NOT FOUND (∞,n)-category_theory
# NOT FOUND 0-bundle
# NOT FOUND 0-category
# NOT FOUND 0-dimensional_TQFT
# NOT FOUND 0-functor
# NOT FOUND 0-groupoid
# NOT FOUND 0-morphism
# NOT FOUND 0-object_>_history
# NOT FOUND 0-poset
# SUGG 0-sphere found: Q306610
# NOT FOUND 1-category
# NOT FOUND 1-category_equipped_with_relations
# NOT FOUND 1-dimensional_Chern-Simons_theory
# NOT FOUND 1-functor
# NOT FOUND 1-groupoid
# NOT FOUND 1-morphism
# NOT FOUND 1-poset
# NOT FOUND 1-topos
# NOT FOUND 10d_supergravity
# NOT FOUND 10j_symbol
# NOT FOUND 11-dimensional_Chern-Simons_theory
# NOT FOUND 11d_SuGra_from_super_C-field_flux_quantization_--_section
# NOT FOUND 11d_supergravity_Lie_3-algebra
# SUGG 120-cell found: Q736191
# NOT FOUND 13-sphere
# NOT FOUND 15-sphere
# NOT FOUND 1d_Dijkgraaf-Witten_theory
# NOT FOUND 1d_WZW_model
# NOT FOUND 1lab
# NOT FOUND 1T_relation
# NOT FOUND 2-adjunction
# NOT FOUND 2-algebraic_geometry
# NOT FOUND 2-categorical_limit_>_history
# SUGG 2-category found: Q4596935
# NOT FOUND 2-category_equipped_with_proarrows
# NOT FOUND 2-category_of_2-dimensional_cobordisms
# NOT FOUND 2-category_of_adjunctions
# NOT FOUND 2-category_theory
# NOT FOUND 2-category_theory_-_contents
# NOT FOUND 2-category_with_contravariance
# NOT FOUND 2-congruence
# NOT FOUND 2-crossed_complex
# NOT FOUND 2-crossed_module
# NOT FOUND 2-dinatural_transformation
# SUGG 2-functor found: Q25304059
# NOT FOUND 2-gerbe
# NOT FOUND 2-Giraud_theorem
# NOT FOUND 2-Grothendieck_construction
# SUGG 2-group found: Q4596948
# NOT FOUND 2-groupoid
# NOT FOUND 2-groupoid_of_Lie_2-algebra_valued_forms
# NOT FOUND 2-Hilbert_space
# NOT FOUND 2-isomorphism
# NOT FOUND 2-Lawvere_theory
# NOT FOUND 2-limit
# NOT FOUND 2-limits_and_2-colimits_in_2-categories_of_2-algebras
# NOT FOUND 2-line
# NOT FOUND 2-logic
# NOT FOUND 2-monad
# SUGG 2-morphism found: Q4596935
# NOT FOUND 2-morphism_-_SVG
# NOT FOUND 2-morphisms_>_history
# NOT FOUND 2-periodic_Morava_K-theory
# NOT FOUND 2-periodic_sphere_spectrum
# NOT FOUND 2-plectic_geometry
# NOT FOUND 2-plethory
# NOT FOUND 2-polycategory
# NOT FOUND 2-poset
# NOT FOUND 2-poset_of_partial_maps
# NOT FOUND 2-presheaf
# NOT FOUND 2-pretopos
# NOT FOUND 2-pro-object
# NOT FOUND 2-pullback
# NOT FOUND 2-representation
# NOT FOUND 2-rig
# SUGG 2-sheaf found: Q7595945
# NOT FOUND 2-site
# NOT FOUND 2-spectral_triple
# NOT FOUND 2-topos
# NOT FOUND 2-topos_theory
# NOT FOUND 2-trivial_model_structure
# NOT FOUND 2-type_>_history
# NOT FOUND 2-type_theory
# NOT FOUND 2-vector_bundle
# SUGG 2-vector_space found: Q663908
# NOT FOUND 2008_changes
# NOT FOUND 2009_April_changes
# NOT FOUND 2009_August_changes
# NOT FOUND 2009_February_changes
# NOT FOUND 2009_January_changes
# NOT FOUND 2009_July_changes
# NOT FOUND 2009_June_changes
# NOT FOUND 2009_March_changes
# NOT FOUND 2009_May_changes
# NOT FOUND 2009_September_changes
# NOT FOUND 24
# NOT FOUND 24_branes_transverse_to_K3
# SUGG 24-cell found: Q539008
# NOT FOUND 2Cat
# NOT FOUND 2d_Chern-Simons_theory
# NOT FOUND 2d_quantum_gravity
# NOT FOUND 2d_SCFT
# NOT FOUND 2d_TQFT
# NOT FOUND 2d_TQFT_--_table
# NOT FOUND 2d_Wess-Zumino-Witten_theory
# NOT FOUND 2Mod
# NOT FOUND 2T_relation
# NOT FOUND 3-brane_in_6d
# SUGG 3-category found: Q5758318
# NOT FOUND 3-category_of_fermionic_conformal_nets
# NOT FOUND 3-category_with_contravariance
# NOT FOUND 3-group
# NOT FOUND 3-groupoid
# NOT FOUND 3-groupoid_of_Lie_3-algebra_valued_forms
# SUGG 3-manifold found: Q526901
# NOT FOUND 3-morphism
# NOT FOUND 3-poset
# SUGG 3-sphere found: Q2274197
# NOT FOUND 3-strand-braid-1-SVG
# NOT FOUND 3-theory
# NOT FOUND 3d_Calabi-Yau_object
# NOT FOUND 3d_Chern-Simons_theory
# NOT FOUND 3d_gravity_and_Chern-Simons_theory_--_references
# NOT FOUND 3d_mirror_symmetry
# NOT FOUND 3d_quantum_gravity
# NOT FOUND 3d_superconformal_gauge_field_theory
# NOT FOUND 3d_toric_code
# NOT FOUND 3d_TQFT
# NOT FOUND 3d-3d_correspondence
# NOT FOUND 3x3_lemma
# NOT FOUND 4-3-2_8-7-6
# SUGG 4-manifold found: Q2566544
# SUGG 4-sphere found: Q306610
# NOT FOUND 4d_Chern-Simons_theory
# NOT FOUND 4d_superconformal_gauge_field_theory
# NOT FOUND 4d_supergravity_Lie_2-algebra
# NOT FOUND 4d_TQFT
# NOT FOUND 4d_WZW_model
# NOT FOUND 4T_relation
# SUGG 5-manifold found: Q4639668
# SUGG 5-sphere found: Q306610
# SUGG 6-sphere found: Q306610
# SUGG 600-cell found: Q2610844
# NOT FOUND 6d_Chern-Simons_theory
# SUGG 6j_symbol found: Q2606520
# SUGG 7-sphere found: Q306610
# NOT FOUND 7d_Chern-Simons_theory
# NOT FOUND 7d_spherical_space_forms_--_table
# NOT FOUND 8-manifold
# SUGG 8-sphere found: Q306610
# NOT FOUND 9-dimensional_supergravity
# NOT FOUND A_Categorical_Manifesto
# NOT FOUND A_Concise_Course_in_Algebraic_Topology
# NOT FOUND A_crash_course_in_topos_theory_--_The_big_picture
# NOT FOUND A_Cubical_Approach_to_Synthetic_Homotopy_Theory
# NOT FOUND A_first_idea_of_quantum_field_theory_--_Feynman_diagrams
# NOT FOUND A_first_idea_of_quantum_field_theory_--_Field_variations
# NOT FOUND A_first_idea_of_quantum_field_theory_--_Fields
# NOT FOUND A_first_idea_of_quantum_field_theory_--_Free_quantum_fields
# NOT FOUND A_first_idea_of_quantum_field_theory_--_Gauge_fixing
# NOT FOUND A_first_idea_of_quantum_field_theory_--_Gauge_symmetries
# NOT FOUND A_first_idea_of_quantum_field_theory_--_Geometry
# NOT FOUND A_first_idea_of_quantum_field_theory_--_Interacting_quantum_fields
# NOT FOUND A_first_idea_of_quantum_field_theory_--_Lagrangians
# NOT FOUND A_first_idea_of_quantum_field_theory_--_Observables
# NOT FOUND A_first_idea_of_quantum_field_theory_--_Phase_space
# NOT FOUND A_first_idea_of_quantum_field_theory_--_Propagators
# NOT FOUND A_first_idea_of_quantum_field_theory_--_Quantization
# NOT FOUND A_first_idea_of_quantum_field_theory_--_Quantum_electrodynamics
# NOT FOUND A_first_idea_of_quantum_field_theory_--_Reduced_phase_space
# NOT FOUND A_first_idea_of_quantum_field_theory_--_Renormalization
# NOT FOUND A_first_idea_of_quantum_field_theory_--_Scattering
# NOT FOUND A_first_idea_of_quantum_field_theory_--_Spacetime
# NOT FOUND A_first_idea_of_quantum_field_theory_--_Symmetries
# NOT FOUND A_first_idea_of_quantum_field_theory_>_history
# SUGG A_History_of_Western_Philosophy found: Q133740
# NOT FOUND A_mechanization_of_the_Blakers-Massey_connectivity_theorem_in_Homotopy_Type_Theory
# NOT FOUND A_Not-So-Nice_Submanifold
# NOT FOUND A_Polarized_View_of_String_Topology
# NOT FOUND A_pseudo_metric_space,_i.e._a_set_with_a_metric_where_the_distance_between_two_distinct_points_can_also_be_0,_need_not_be_Haussdorf
# NOT FOUND A_Serre_fibration_between_CW-complexes_is_a_Hurewicz_fibration
# NOT FOUND A_string_diagram_calculus_for_predicate_logic
# NOT FOUND A_study_in_derived_algebraic_geometry
# NOT FOUND A_Survey_of_Cohomological_Physics
# NOT FOUND A_Survey_of_Elliptic_Cohomology
# NOT FOUND A_Survey_of_Elliptic_Cohomology_-_A-equivariant_cohomology
# NOT FOUND A_Survey_of_Elliptic_Cohomology_-_cohomology_theories
# NOT FOUND A_Survey_of_Elliptic_Cohomology_-_compactifying_the_derived_moduli_stack
# NOT FOUND A_Survey_of_Elliptic_Cohomology_-_derived_group_schemes_and_(pre-)orientations
# NOT FOUND A_Survey_of_Elliptic_Cohomology_-_descent_ss_and_coefficients
# NOT FOUND A_Survey_of_Elliptic_Cohomology_-_E-infinity_rings_and_derived_schemes
# NOT FOUND A_Survey_of_Elliptic_Cohomology_-_elliptic_curves
# NOT FOUND A_Survey_of_Elliptic_Cohomology_-_equivariant_cohomology
# NOT FOUND A_Survey_of_Elliptic_Cohomology_-_formal_groups_and_cohomology
# NOT FOUND A_Survey_of_Elliptic_Cohomology_-_the_derived_moduli_stack_of_derived_elliptic_curves
# NOT FOUND A_Survey_of_Elliptic_Cohomology_-_towards_a_proof
# NOT FOUND A-brane
# SUGG A-hat_genus found: Q5533833
# NOT FOUND A-infinity_algebra_>_history
# NOT FOUND A-infinity_category_>_history
# SUGG A-infinity_operad found: Q4833569
# NOT FOUND A-infinity_operad_>_history
# NOT FOUND A-infinity-algebra
# NOT FOUND A-infinity-category
# NOT FOUND A-infinity-cocategory
# NOT FOUND A-infinity-module
# NOT FOUND A-infinity-ring
# NOT FOUND A-infinity-space
# NOT FOUND A-model
# NOT FOUND A-n_space
# NOT FOUND A-theory
# NOT FOUND A._Ch._Ganchev
# NOT FOUND A._G._Walker
# NOT FOUND A._J._Tolland_>_history
# SUGG A._P._Balachandran found: Q4648223
# NOT FOUND A._Yung
# NOT FOUND A.A._Sharapov
# NOT FOUND A1
# NOT FOUND A1-cohesive_homotopy_type_theory
# NOT FOUND A1-meson
# NOT FOUND A2
# NOT FOUND A3
# NOT FOUND A4-spatial_groupoid_>_history
# NOT FOUND Aarne_Ranta
# NOT FOUND Aaron_Bergman
# NOT FOUND Aaron_F
# NOT FOUND Aaron_Greicius
# NOT FOUND Aaron_Lauda
# NOT FOUND Aaron_M._Smith
# NOT FOUND Aaron_Mazel-Gee
# NOT FOUND Aaron_Stump
# NOT FOUND Ab
# NOT FOUND Ab-enriched_category
# SUGG Abc_conjecture found: Q306393
# NOT FOUND Abdelmalek_Abdesselam
# SUGG Abductive_reasoning found: Q308495
# SUGG Abdus_Salam found: Q28189
# SUGG Abel-Jacobi_map found: Q4666729
# NOT FOUND Abelian_2-category
# NOT FOUND Abelian_3-group
# NOT FOUND Abelian_4-group
# NOT FOUND Abelian_7-group
# NOT FOUND Abelian_categories_with_applications_to_rings_and_modules
# SUGG Abelian_category found: Q318737
# NOT FOUND Abelian_differential_graded_Lie_algebra
# SUGG Abelian_group found: Q181296
# NOT FOUND Abelian_infinity-group
# SUGG Abelian_Lie_algebra found: Q664495
# NOT FOUND Abelian_model_category
# SUGG Abelian_sheaf found: Q18695611
# NOT FOUND Abelian_sheaf_cohomology
# NOT FOUND Abelian_subcategory
# SUGG Abelian_variety found: Q318751
# SUGG Abelianization found: Q522216
# NOT FOUND Abhijit_Champanerkar
# NOT FOUND Abhijit_Gadde
# SUGG Abhishek_Banerjee found: Q4667463
# NOT FOUND ABJM_theory
# NOT FOUND AbMon_>_history
# SUGG Abner_Shimony found: Q2903381
# NOT FOUND About
# SUGG Abraham_Adrian_Albert found: Q323442
# SUGG Abraham_Fraenkel found: Q61043
# SUGG Abraham_Robinson found: Q330567
# NOT FOUND Abraham_Westerbaan
# NOT FOUND Abrupt_category
# SUGG Absolute_coequalizer found: Q5140810
# NOT FOUND Absolute_cohomology
# NOT FOUND Absolute_colimit
# NOT FOUND Absolute_conclusion
# SUGG Absolute_convergence found: Q332465
# NOT FOUND Absolute_de_Rham_cohomology
# NOT FOUND Absolute_differential_form
# NOT FOUND Absolute_extensor
# SUGG Absolute_Galois_group found: Q332407
# SUGG Absolute_idealism found: Q13474384
# NOT FOUND Absolute_pushout
# SUGG Absolute_retract found: Q2141963
# SUGGCAT Absolute_value_(mathematics) found: Q120812
# SUGG Absolute_zero found: Q81182
# SUGG Absolutely_continuous_function found: Q332504
# SUGG Absolutely_continuous_measure found: Q332504
# NOT FOUND Absolutely_convex_subset
# NOT FOUND Absolutely_dense_functor
# NOT FOUND Absorbing_subset
# NOT FOUND Absorption_category
# NOT FOUND Absorption_magma
# NOT FOUND Absorption_monoid
# NOT FOUND Abstract_and_Concrete_Categories
# NOT FOUND Abstract_circle
# SUGG Abstract_elementary_class found: Q4669945
# NOT FOUND Abstract_general,_concrete_general_and_concrete_particular
# NOT FOUND Abstract_Homotopy_and_Simple_Homotopy_Theory
# SUGG Abstract_model_theory found: Q4669950
# SUGG Abstract_rewriting_system found: Q2136420
# NOT FOUND Abstract_scattering_theory
# NOT FOUND Abstract_Stone_duality
# SUGG Abstract_syntax_tree found: Q127380
# SUGGCAT Abstraction_(mathematics) found: Q4669982
# NOT FOUND AccCat
# SUGGCAT Acceleration_(differential_geometry) found: Q25203193
# NOT FOUND Accessible_(infinity,1)-category
# NOT FOUND Accessible_(infinity,1)-functor
# SUGG Accessible_category found: Q4672496
# SUGG Accessible_functor found: Q4672496
# NOT FOUND Accessible_model_category
# NOT FOUND Accessible_monad
# NOT FOUND Accessible_topological_space
# NOT FOUND Accessible_weak_factorization_system
# NOT FOUND Achim_Jung
# NOT FOUND Achim_Krause
# NOT FOUND Ackermann_groupoid
# SUGG Acoustics found: Q82811
# SUGGCAT Action_(group_theory) found: Q288465
# NOT FOUND Action_(physics)_-_table
# NOT FOUND Action_functional
# NOT FOUND Action_group_>_history
# NOT FOUND Action_groupoid
# NOT FOUND Action_Lie_algebroid
# NOT FOUND Action_monad
# NOT FOUND Action_object_>_history
# NOT FOUND Action_of_a_category_on_a_set
# NOT FOUND Action_of_a_monoidal_category
# NOT FOUND Acyclic_assembly_lemma
# NOT FOUND Acyclic_fibration
# NOT FOUND Acyclic_graph
# SUGG Acyclic_group found: Q4677988
# NOT FOUND Acyclic_Kan_fibration
# SUGG Acyclic_object found: Q4677987
# NOT FOUND Acyclic_type
# SUGG Adam found: Q70899
# NOT FOUND Adam_Brandenburger
# NOT FOUND Adam_Chlipala
# NOT FOUND Adam_Falkowski
# SUGG Adam_G._Riess found: Q106454
# NOT FOUND Adam_Keenan
# NOT FOUND Adam_Krupicka
# NOT FOUND Adam_Lewandowski
# SUGG Adam_Marsh found: Q2606307
# NOT FOUND Adam_Petcher
# NOT FOUND Adams_category
# SUGG Adams_conjecture found: Q6103838
# SUGG Adams_e-invariant found: Q6103838
# SUGG Adams_operation found: Q4680478
# NOT FOUND Adams_operation_on_Jacobi_diagrams
# NOT FOUND Adams_operations_compatible_with_the_Chern_character
# NOT FOUND Adams_resolution
# SUGG Adams_spectral_sequence found: Q4680481
# NOT FOUND Adams-Quillen_theorem
# SUGG Adams–Novikov_spectral_sequence found: Q4680481
# NOT FOUND Additive_(infinity,1)-category
# NOT FOUND Additive_analytic_geometry
# NOT FOUND Additive_and_abelian_categories
# NOT FOUND Additive_and_abelian_categories_-_contents
# SUGG Additive_category found: Q4681343
# NOT FOUND Additive_disjunction
# NOT FOUND Additive_envelope
# SUGG Additive_functor found: Q2099981
# SUGG Additive_K-theory found: Q4681337
# SUGG Additive_monad found: Q1579914
# NOT FOUND ADE_--_table
# SUGG ADE_classification found: Q2976517
# NOT FOUND ADE_singularity
# NOT FOUND Adeel_Khan
# NOT FOUND Adel_Bilal
# NOT FOUND Adelic_integral
# SUGG Adequate_equivalence_relation found: Q4682344
# NOT FOUND Adequate_subcategory_>_history
# SUGG Adhesive_category found: Q17001823
# SUGG ADHM_construction found: Q4651121
# SUGG Adiabatic found: Q182453
# SUGG Adiabatic_quantum_computation found: Q4682635
# NOT FOUND Adiabatic_switching
# NOT FOUND Adic_noetherian_ring
# NOT FOUND Adic_residual
# NOT FOUND Adic_ring_>_history
# SUGG Adic_space found: Q7333799
# NOT FOUND Adic_topology_>_history
# NOT FOUND Adinkra
# NOT FOUND Adj
# SUGG Adjacency_matrix found: Q727035
# NOT FOUND Adjoint
# NOT FOUND Adjoint_(infinity,1)-functor
# NOT FOUND Adjoint_(infinity,1)-functor_theorem
# SUGG Adjoint_action found: Q1017106
# SUGG Adjoint_bundle found: Q4683171
# NOT FOUND Adjoint_equivalence
# SUGG Adjoint_functor found: Q357858
# SUGG Adjoint_functor_theorem found: Q357858
# NOT FOUND Adjoint_lifting_theorem
# NOT FOUND Adjoint_logic
# NOT FOUND Adjoint_modality
# NOT FOUND Adjoint_monad
# NOT FOUND Adjoint_morphism
# SUGG Adjoint_operator found: Q1509647
# NOT FOUND Adjoint_quadruple
# SUGG Adjoint_representation found: Q1017106
# NOT FOUND Adjoint_string
# NOT FOUND Adjoint_triangle_theorem
# NOT FOUND Adjoint_triple
# NOT FOUND Adjointification_zigzag_identity_-_SVG
# NOT FOUND Adjointness_for_2-Categories
# NOT FOUND Adjointness_in_Foundations
# NOT FOUND Adjoints_preserve_(co-)limits
# NOT FOUND Adjunct
# SUGGCAT Adjunction_(category_theory) found: Q357858
# NOT FOUND Adjunction_>_zigzagepsilon
# NOT FOUND Adjunction_>_zigzageta
# NOT FOUND Adjunction_>_zigzageta_>_history
# NOT FOUND Adjunction_between_topological_spaces_and_diffeological_spaces
# NOT FOUND Adjunction_of_dg-categories
# NOT FOUND Adjusted_connection
# NOT FOUND Adjusted_Weil_algebra
# SUGG ADM_mass found: Q290420
# NOT FOUND Admin_>_history
# NOT FOUND Admir_Greljo
# SUGG Admissible_rule found: Q1560157
# NOT FOUND Admissible_subcategory
# SUGG Adolf_Hurwitz found: Q58809
# NOT FOUND Adrian_Clingher
# NOT FOUND Adrian_Clough
# NOT FOUND Adrian_Norbert_Schellekens
# SUGG Adrian_Ocneanu found: Q7076681
# NOT FOUND Adriano_Barenco
# NOT FOUND Adrien_Bouhon
# NOT FOUND Adrien_Brochier
# SUGG Adrien_Douady found: Q376963
# SUGG Adrien-Marie_Legendre found: Q191021
# NOT FOUND AdS-CFT_correspondence
# NOT FOUND AdS-CFT_in_condensed_matter_physics
# NOT FOUND AdS-QCD_correspondence
# NOT FOUND AdS2-CFT1_--_references
# NOT FOUND AdS3-CFT2_and_CS-WZW_correspondence
# NOT FOUND AdS3-CFT2_on_D1-D5_branes_--_references
# NOT FOUND AdS3-CFT2_on_D2-D4-D6-D8_branes_--_references
# NOT FOUND Advanced_and_retarded_causal_propagators
# SUGG Ady_Stern found: Q4686923
# NOT FOUND Adámek's_fixed_point_theorem
# NOT FOUND Aeysha_Khalique
# SUGG Affiliated_operator found: Q4688920
# NOT FOUND Affine_algebra
# SUGG Affine_connection found: Q1371213
# SUGG Affine_Grassmannian found: Q4688931
# SUGG Affine_group found: Q686291
# SUGG Affine_group_scheme found: Q5611270
# SUGG Affine_Lie_algebra found: Q632521
# SUGG Affine_line found: Q382698
# NOT FOUND Affine_localization
# SUGG Affine_logic found: Q4688943
# NOT FOUND Affine_modality
# NOT FOUND Affine_monad
# SUGG Affine_morphism found: Q48971898
# SUGG Affine_scheme found: Q1154351
# SUGGCAT Affine_space_(algebraic_geometry) found: Q382698
# NOT FOUND Affine_symplectic_group
# SUGG Affine_variety found: Q3554813
# NOT FOUND Affinoid
# NOT FOUND Affinoid_algebra
# NOT FOUND Affinoid_domain
# NOT FOUND Affinoid_space
# NOT FOUND Agda
# NOT FOUND Age
# NOT FOUND Agnese_Bissi
# NOT FOUND Agnès_Beaudry
# NOT FOUND AGT_conjecture_>_history
# SUGG AGT_correspondence found: Q17338668
# NOT FOUND Agustí_Roig
# NOT FOUND Aharon_Casher
# SUGG Aharonov-Bohm_effect found: Q400083
# SUGG Ahmadnagar found: Q223517
# NOT FOUND Ahmed_Almheiri
# NOT FOUND Aidan_Herderschee
# SUGG Airy_function found: Q409415
# SUGG Aise_Johan_de_Jong found: Q371475
# NOT FOUND AJ_Tolland
# SUGG Akash_Singh found: Q58215574
# NOT FOUND Akhil_Mathew
# NOT FOUND Akihiko_Sonoda
# NOT FOUND Akikazu_Hashimoto
# NOT FOUND Akira_Furusaki
# SUGG Akira_Kono found: Q4701148
# SUGG Akshay_Venkatesh found: Q176588
# NOT FOUND AKSZ_sigma-model
# SUGG Alain_Aspect found: Q364997
# NOT FOUND Alain_Bruguières
# SUGG Alain_Connes found: Q313590
# NOT FOUND Alain_Joye
# NOT FOUND Alain_Prouté
# NOT FOUND Alain_Valette
# NOT FOUND Alain_Verschoren
# SUGG Alan_Carey found: Q4706323
# NOT FOUND Alan_Coley
# SUGG Alan_Guth found: Q323316
# NOT FOUND Alan_Hatcher_>_history
# NOT FOUND Alan_Hatcher_>_history_2
# NOT FOUND Alan_J._Deschner
# SUGG Alan_M._Turing found: Q7251
# SUGG Alan_Martin found: Q4707254
# SUGG Alan_Mycroft found: Q4707402
# SUGG Alan_Robinson found: Q23538264
# NOT FOUND Alan_S._Cigoli
# SUGG Alan_Weinstein found: Q381300
# NOT FOUND Alastair_Craw
# NOT FOUND Alastair_Grant-Stuart
# SUGG Alastair_Hamilton found: Q20876161
# SUGG Alastair_King found: Q4708729
# SUGG Alastair_Wilson found: Q4708787
# SUGG Albanese_variety found: Q4709029
# SUGG Albert_algebra found: Q12204658
# NOT FOUND Albert_Blakers
# NOT FOUND Albert_Burroni
# SUGG Albert_Einstein found: Q937
# NOT FOUND Albert_Georg_Passegger
# SUGG Albert_Lautman found: Q327198
# SUGG Albert_Nijenhuis found: Q1464744
# NOT FOUND Albert_R._Hibbs
# NOT FOUND Albert_Schwartz_>_history
# SUGG Albert_Schwarz found: Q2638692
# NOT FOUND Alberto_Cattaneo
# NOT FOUND Alberto_Elduque
# NOT FOUND Alberto_Facchini
# NOT FOUND Alberto_Gandolfi
# NOT FOUND Alberto_García_Raboso
# NOT FOUND Alberto_Marchisio
# NOT FOUND Alberto_Verjovsky
# NOT FOUND Alberto_Vezzani
# NOT FOUND Alberto_Zaffaroni
# NOT FOUND Albrecht_Bertram
# SUGG Albrecht_Dold found: Q109854
# SUGG Albrecht_Fröhlich found: Q451721
# NOT FOUND Albrecht_Klemm
# NOT FOUND Alcides_Buss
# NOT FOUND Aldridge_Bousfield
# SUGG ALE_space found: Q5597999
# SUGG Alejandro_Adem found: Q2640723
# SUGG Alejandro_Corichi found: Q4714507
# NOT FOUND Alejandro_Uribe
# NOT FOUND Aleks_Kissinger
# NOT FOUND Aleksandar_Mikovic
# NOT FOUND Aleksandar_Nanevski
# NOT FOUND Aleksandr_A._Zheltukhin
# SUGG Aleksandr_Aleksandrov found: Q344518
# NOT FOUND Aleksei_Starobinsky
# SUGG Aleph found: Q15033
# SUGG Alessandra_Buonanno found: Q4716267
# NOT FOUND Alessandra_Di_Pierro
# NOT FOUND Alessandro_Luongo
# NOT FOUND Alessandro_Nagar
# SUGG Alessandro_Strumia found: Q56849337
# NOT FOUND Alessandro_Tomasiello
# NOT FOUND Alessandro_Torrielli
# NOT FOUND Alessandro_Valentino
# NOT FOUND Alessandro_Vichi
# NOT FOUND Alessio_Lomuscio
# NOT FOUND Alessio_Marrani
# NOT FOUND Alex_Arvanitakis
# SUGG Alex_Cole found: Q4716836
# SUGG Alex_Eskin found: Q1748305
# NOT FOUND Alex_Heller
# NOT FOUND Alex_Hoffnung
# NOT FOUND Alex_Kavvos
# NOT FOUND Alex_Kehagias
# SUGG Alex_Simpson found: Q4717793
# NOT FOUND Alexander_A._Migdal
# NOT FOUND Alexander_B._Atanasov
# SUGG Alexander_Beilinson found: Q369792
# SUGG Alexander_Belavin found: Q2641669
# NOT FOUND Alexander_Belopolsky
# NOT FOUND Alexander_Berenbeim
# NOT FOUND Alexander_Berglund
# NOT FOUND Alexander_Bobenko
# SUGG Alexander_Braverman found: Q2641863
# SUGG Alexander_Campbell found: Q82750
# NOT FOUND Alexander_Efimov
# SUGG Alexander_Engel found: Q99544
# SUGG Alexander_Givental found: Q451757
# NOT FOUND Alexander_Gnedin
# SUGG Alexander_Goncharov found: Q2642205
# SUGG Alexander_Gorsky found: Q980208
# SUGG Alexander_Green found: Q4703912
# SUGG Alexander_Grothendieck found: Q77141
# NOT FOUND Alexander_Haupt
# NOT FOUND Alexander_Jahn
# NOT FOUND Alexander_K._Zvonkin
# NOT FOUND Alexander_Kahle
# NOT FOUND Alexander_Karabegov
# SUGG Alexander_Kirillov found: Q4221363
# NOT FOUND Alexander_Kupers
# NOT FOUND Alexander_Kurz
# SUGG Alexander_Kuznetsov found: Q1900592
# NOT FOUND Alexander_Körschgen
# SUGG Alexander_L._Fetter found: Q4718839
# NOT FOUND Alexander_Lenz
# SUGG Alexander_Merkurjev found: Q2642658
# NOT FOUND Alexander_Odesskii
# SUGG Alexander_Ostrowski found: Q64975
# SUGG Alexander_Polishchuk found: Q16734607
# SUGG Alexander_Polyakov found: Q1727208
# SUGG Alexander_polynomial found: Q1634206
# SUGG Alexander_Popov found: Q620780
# SUGG Alexander_Postnikov found: Q4374246
# NOT FOUND Alexander_Reznikov
# SUGG Alexander_Rosenberg found: Q3739981
# NOT FOUND Alexander_Schenkel
# NOT FOUND Alexander_Schmeding
# SUGG Alexander_Schmidt found: Q2642974
# NOT FOUND Alexander_Sevrin
# NOT FOUND Alexander_Stottmeister
# NOT FOUND Alexander_Strohmaier
# SUGG Alexander_Varchenko found: Q1458824
# NOT FOUND Alexander_Verbovetsky
# SUGG Alexander_Vilenkin found: Q1399445
# SUGG Alexander_Voronov found: Q12271434
# NOT FOUND Alexander_W._Smith
# NOT FOUND Alexander_Westphal
# SUGG Alexander_Zamolodchikov found: Q1333246
# SUGG Alexander's_trick found: Q4718108
# NOT FOUND Alexander-Whitney_map
# NOT FOUND Alexander-Čech_duality
# NOT FOUND Alexandr_S._Mishchenko
# NOT FOUND Alexandre_Deur
# SUGG Alexandre_Kirillov found: Q925405
# NOT FOUND Alexandre_Miquel
# NOT FOUND Alexandre_Vinogradov
# NOT FOUND Alexandros_Anastasiou
# SUGG Alexandrov_space found: Q28401130
# NOT FOUND Alexandru_Buium
# NOT FOUND Alexandru_Chirvasitu
# SUGG Alexandru_Dimca found: Q22328386
# NOT FOUND Alexandru_E._Stanculescu
# SUGG Alexandru_Proca found: Q2277954
# NOT FOUND Alexandru_Solian
# SUGG Alexei_Abrikosov found: Q1183421
# NOT FOUND Alexei_Bondal
# NOT FOUND Alexei_Davydov
# SUGG Alexei_Kitaev found: Q2643958
# SUGG Alexei_Kovalev found: Q739944
# NOT FOUND Alexei_M._Tsvelik
# SUGG Alexei_Morozov found: Q735366
# NOT FOUND Alexei_Nurmagambetov
# NOT FOUND Alexei_Oblomkov
# NOT FOUND Alexei_P._Kopylov
# NOT FOUND Alexei_Pirkovskii
# NOT FOUND Alexey_O._Remizov
# SUGG Alexey_Petrov found: Q82993
# NOT FOUND Alexey_Slinkin
# NOT FOUND Alexis_Hazell
# NOT FOUND Alexis_Toumi
# NOT FOUND Alexis_Virelizier
# NOT FOUND Aleš_Pultr
# SUGG Alfred_Ewing found: Q936470
# SUGG Alfred_Frölicher found: Q4722697
# SUGG Alfred_Gray found: Q4722749
# NOT FOUND Alfred_Rieckers
# SUGG Alfred_Schild found: Q85471
# SUGG Alfred_Tarski found: Q207534
# SUGG Alfred_Whitehead found: Q4723614
# SUGG Alfred_Young found: Q534624
# SUGG Alfréd_Rényi found: Q465715
# NOT FOUND Alfsen-Shultz_theorem
# NOT FOUND Alg
# NOT FOUND Alg(T)_>_history
# SUGGCAT Algebra_(mathematics) found: Q3968
# SUGG Algebra_extension found: Q1166643
# NOT FOUND Algebra_for_a_profunctor
# SUGG Algebra_for_an_endofunctor found: Q1386213
# NOT FOUND Algebra_for_an_endomorphism
# NOT FOUND Algebra_modality
# NOT FOUND Algebra_of_an_endofunctor_>_history
# NOT FOUND Algebra_of_functions
# NOT FOUND Algebra_over_a_Lawvere_theory
# SUGG Algebra_over_a_monad found: Q1630568
# SUGG Algebra_over_an_operad found: Q16827071
# NOT FOUND Algebra_spectrum
# NOT FOUND Algebrad
# SUGG Algebraic_analysis found: Q4723988
# NOT FOUND Algebraic_approaches_to_differential_calculus
# SUGG Algebraic_category found: Q3502010
# SUGG Algebraic_cobordism found: Q4723991
# NOT FOUND Algebraic_correspondences
# SUGG Algebraic_curve found: Q266237
# SUGG Algebraic_cycle found: Q4723996
# NOT FOUND Algebraic_definition_of_higher_categories
# SUGG Algebraic_dynamics found: Q4791123
# NOT FOUND Algebraic_effect
# SUGG Algebraic_element found: Q162608
# SUGG Algebraic_equation found: Q50698
# SUGG Algebraic_extension found: Q550791
# SUGG Algebraic_function found: Q746863
# SUGG Algebraic_fundamental_group found: Q288764
# SUGG Algebraic_geometry found: Q180969
# SUGG Algebraic_group found: Q1695400
# NOT FOUND Algebraic_Homotopy
# NOT FOUND Algebraic_homotopy
# SUGG Algebraic_integer found: Q646245
# SUGG Algebraic_K-theory found: Q2553675
# NOT FOUND Algebraic_K-theory_of_smooth_manifolds
# NOT FOUND Algebraic_K-theory_spectrum
# NOT FOUND Algebraic_K-theory,_a_historical_perspective
# NOT FOUND Algebraic_Kan_complex
# SUGG Algebraic_lattice found: Q5155306
# NOT FOUND Algebraic_Lefschetz_formula
# NOT FOUND Algebraic_limit_field
# NOT FOUND Algebraic_limit_vector_space
# NOT FOUND Algebraic_line_bundle
# NOT FOUND Algebraic_line_n-bundle
# NOT FOUND Algebraic_microlocalization
# NOT FOUND Algebraic_model_category
# NOT FOUND Algebraic_model_for_modal_logics
# NOT FOUND Algebraic_model_structures_-_table
# SUGG Algebraic_number found: Q168817
# SUGG Algebraic_number_theory found: Q613048
# NOT FOUND Algebraic_pattern
# NOT FOUND Algebraic_quasi-category
# NOT FOUND Algebraic_set_theory
# NOT FOUND Algebraic_small_object_argument
# SUGG Algebraic_space found: Q4724016
# NOT FOUND Algebraic_spaces_>_history
# SUGG Algebraic_stack found: Q7595945
# SUGG Algebraic_structure found: Q205464
# SUGG Algebraic_surface found: Q1434805
# NOT FOUND Algebraic_theories_in_functional_analysis
# SUGG Algebraic_theory found: Q4724020
# SUGG Algebraic_topology found: Q212803
# NOT FOUND Algebraic_topology_-_contents
# NOT FOUND Algebraic_triangulated_category
# SUGG Algebraic_variety found: Q648995
# SUGG Algebraic_vector_bundle found: Q906907
# NOT FOUND Algebraic_weak_factorization_system
# SUGG Algebraically_closed_field found: Q1047547
# NOT FOUND Algebraically_compact_category
# NOT FOUND Algebraically_independent_subset
# NOT FOUND Algebraically_injective_object
# NOT FOUND Algebras_>_history
# NOT FOUND Algebroid
# SUGG Algimantas_Adolfas_Jucys found: Q4724234
# SUGG Algorithm found: Q8366
# NOT FOUND Algèbres_Enveloppantes
# NOT FOUND Ali_Caglayan
# SUGG Ali_Chamseddine found: Q17521164
# NOT FOUND Ali_Mozaffari
# NOT FOUND Ali_Ovgun_>_history
# SUGG Alice_Rogers found: Q24572773
# NOT FOUND Alisa_Govzmann
# SUGG Alissa_Crans found: Q58010066
# NOT FOUND Alistair_Savage
# NOT FOUND All_arrows_monic_>_history
# NOT FOUND All_changes
# NOT FOUND All_horizontal_weight_systems_are_partitioned_Lie_algebra_weight_systems
# NOT FOUND All_Pages_>_history
# NOT FOUND Allan_J._Silberger
# NOT FOUND Allan_L._Edelson
# NOT FOUND Allan_Merino
# NOT FOUND Allegorical_set_theory
# SUGGCAT Allegory_(mathematics) found: Q4731385
# SUGG Allen_Hatcher found: Q2837899
# SUGG Allen_Knutson found: Q4731739
# NOT FOUND Almost_connected_topological_group
# NOT FOUND Almost_equality
# NOT FOUND Almost_function
# NOT FOUND Almost_Hermitian_structure
# NOT FOUND Almost_Kähler_geometric_quantization
# NOT FOUND Almost_module
# NOT FOUND Almost_open_subspace
# NOT FOUND Almost_scheme
# SUGG Almost_surely found: Q1434353
# NOT FOUND Alonso_Botero
# NOT FOUND Alonso_Perez-Lona
# SUGG Alonzo_Church found: Q92741
# SUGG Alpha_particle found: Q103517
# NOT FOUND Alpha-equivalence
# SUGG Alternating_group found: Q438814
# NOT FOUND Alternating_multifunction
# NOT FOUND Alternating_representation
# SUGG Alternative_algebra found: Q2165111
# NOT FOUND Alternative_experimental_definition_of_commutative_diagram
# NOT FOUND Alternative_magmoid
# NOT FOUND Alvaro_Restuccia
# SUGG Amalendu_Krishna found: Q20798882
# NOT FOUND Amalgamation
# SUGG Amalgamation_property found: Q4739384
# NOT FOUND Amalgamation_theory
# SUGG Amanda_Peet found: Q131332
# NOT FOUND Amar_Hadzihasanovic
# NOT FOUND Amaria_Javed
# NOT FOUND Amazing_right_adjoint
# NOT FOUND Ambidexterity_in_K(n)-Local_Stable_Homotopy_Theory
# NOT FOUND Ambidextrous_adjunction
# NOT FOUND Ambient_category
# NOT FOUND Ambimorphic_object_>_history
# NOT FOUND Ambrus_Kaposi
# NOT FOUND Amenable_category
# NOT FOUND Amenable_topological_groupoid
# SUGG Amer_Iqbal found: Q4742444
# NOT FOUND Amihay_Hanany
# NOT FOUND Amir_Dembo
# NOT FOUND Amir-Kian_Kashani-Poor
# NOT FOUND Amirhossein_Tajdini
# NOT FOUND Amit_Giveon
# SUGG Amit_Patel found: Q4746863
# NOT FOUND Amit_Sever
# SUGG Amit_Sharma found: Q4746882
# SUGG Amitai_Regev found: Q4746921
# SUGG Amitsur_complex found: Q60764404
# SUGG Amnestic_functor found: Q4747369
# NOT FOUND Amnon_Neeman
# SUGG Amnon_Yekutieli found: Q14492076
# SUGG Ample_sheaf found: Q4748472
# NOT FOUND Amplimorphism
# SUGG Amplitude found: Q159190
# SUGG Amplituhedron found: Q14928243
# NOT FOUND Amélia_Liao
# NOT FOUND An_Descheemaeker
# NOT FOUND An_elementary_treatment_of_Hilbert_spaces
# NOT FOUND An_Essay_on_the_Foundations_of_Geometry
# NOT FOUND An_Exercise_in_Kantization
# NOT FOUND An_Huang
# NOT FOUND An_Introduction_to_Homological_Algebra
# NOT FOUND Ana_Canas_da_Silva
# SUGG Ana_Cannas_da_Silva found: Q6563512
# NOT FOUND Ana-Maria_Raclariu
# SUGG Anabelian_geometry found: Q483270
# NOT FOUND Anabelian_group
# NOT FOUND Anabelioid
# NOT FOUND Anabicategory
# NOT FOUND Anafunction
# NOT FOUND Anafunctor
# NOT FOUND Anafunctor_category
# SUGG Analogy found: Q185816
# NOT FOUND Analyser
# SUGGCAT Analysis_(mathematics) found: Q7754
# NOT FOUND Analysis_-_contents
# NOT FOUND Analysis_Situs
# NOT FOUND Analytic_(∞,1)-functor
# NOT FOUND Analytic_affine_line
# NOT FOUND Analytic_completion_of_a_ring
# SUGG Analytic_continuation found: Q485287
# SUGG Analytic_function found: Q215084
# SUGG Analytic_geometry found: Q134787
# NOT FOUND Analytic_geometry_--_contents
# NOT FOUND Analytic_geometry_ingredients_--_table
# NOT FOUND Analytic_Langlands_program
# SUGG Analytic_manifold found: Q4751134
# NOT FOUND Analytic_Markov's_principle
# NOT FOUND Analytic_monad
# NOT FOUND Analytic_motives
# NOT FOUND Analytic_motivic_homotopy_theory
# SUGG Analytic_number_theory found: Q10843274
# SUGG Analytic_philosophy found: Q183216
# NOT FOUND Analytic_ring
# SUGG Analytic_space found: Q4751141
# NOT FOUND Analytic_spectrum
# SUGG Analytic_torsion found: Q4751142
# SUGG Analytic_variety found: Q3889649
# NOT FOUND Analytic_versus_synthetic
# NOT FOUND Analytical_index
# NOT FOUND Analytically_continued_Chern-Simons_theory
# NOT FOUND Analytically_continued_Wess-Zumino-Witten_theory
# NOT FOUND Analytification
# NOT FOUND Ananatural_transformation
# NOT FOUND Anand_Dessai
# NOT FOUND Anand_Pillay
# NOT FOUND Ananda_Roy
# NOT FOUND Anastasia_Volovich
# SUGG Anatoly_Libgober found: Q22999228
# SUGG Anatoly_Malcev found: Q487778
# NOT FOUND Anatoly_Shirshov
# SUGG Anatoly_Vershik found: Q451652
# SUGG Anaxagoras found: Q83041
# NOT FOUND Anayeli_Ramirez
# NOT FOUND Anders_Kock
# NOT FOUND Anders_Mörtberg
# NOT FOUND Anders_S._Buch
# NOT FOUND Anderson_duality
# NOT FOUND Andor_Lukacs
# SUGG Andre_Geim found: Q104104
# NOT FOUND Andre_Hirschowitz
# NOT FOUND Andre_Kornell
# NOT FOUND Andre_Lukas
# NOT FOUND Andre_Scedrov
# NOT FOUND Andrea_Amoretti
# NOT FOUND Andrea_Asperti
# NOT FOUND Andrea_Colledan
# NOT FOUND Andrea_Corradini
# NOT FOUND Andrea_Prinsloo
# NOT FOUND Andrea_Vezzosi
# NOT FOUND Andreas_Abel
# SUGG Andreas_Blass found: Q4755386
# NOT FOUND Andreas_Blommaert
# NOT FOUND Andreas_Brandhuber
# NOT FOUND Andreas_Braun
# NOT FOUND Andreas_Crivellin
# NOT FOUND Andreas_Deser
# SUGG Andreas_Dress found: Q496874
# NOT FOUND Andreas_Döring
# SUGG Andreas_Floer found: Q77507
# NOT FOUND Andreas_Gustavsson
# NOT FOUND Andreas_Holmstrom
# NOT FOUND Andreas_Höring
# NOT FOUND Andreas_J._Winter
# NOT FOUND Andreas_Juhl
# NOT FOUND Andreas_Karch
# NOT FOUND Andreas_Kriegl
# NOT FOUND Andreas_Kübel
# NOT FOUND Andreas_Nuyts
# NOT FOUND Andreas_P._Schnyder
# NOT FOUND Andreas_Recknagel
# SUGG Andreas_Thom found: Q500940
# NOT FOUND Andreas_W._W._Ludwig
# SUGG Andreas_Wallraff found: Q30139768
# NOT FOUND Andreas_Wipf
# NOT FOUND Andreas_Čap
# NOT FOUND Andree_Ehresmann
# NOT FOUND Andree_Lischewski
# NOT FOUND Andrei_Constantin
# NOT FOUND Andrei_Khrennikov
# SUGG Andrei_Linde found: Q368087
# NOT FOUND Andrei_Marshakov
# NOT FOUND Andrei_Micu
# SUGG Andrei_Mironov found: Q11561112
# NOT FOUND Andrei_Moroianu
# SUGG Andrei_Okounkov found: Q315425
# NOT FOUND Andrei_Parnachev
# NOT FOUND Andrei_Rodin
# SUGG Andrei_Sakharov found: Q997
# SUGG Andrei_Suslin found: Q501707
# SUGG Andrei_Tyurin found: Q4755981
# NOT FOUND Andrei_V._Prasolov
# SUGG Andrei_Zelevinsky found: Q502771
# NOT FOUND Andrej_Bauer
# NOT FOUND Andrej_Ščedrov
# NOT FOUND Andres_Collinucci
# SUGG Andrew_Baker found: Q28534246
# NOT FOUND Andrew_Blumberg
# NOT FOUND Andrew_Brooke-Taylor
# NOT FOUND Andrew_C._Doherty
# NOT FOUND Andrew_C._Tang
# SUGG Andrew_Childs found: Q23016708
# SUGG Andrew_Gleason found: Q504857
# SUGG Andrew_Hanson found: Q4757226
# SUGG Andrew_Hodges found: Q450154
# NOT FOUND Andrew_Hubery
# SUGG Andrew_Kent found: Q6560871
# NOT FOUND Andrew_Kresch
# NOT FOUND Andrew_Lenard
# SUGG Andrew_Lewis found: Q4757749
# SUGG Andrew_Lucas found: Q27967834
# NOT FOUND Andrew_M._Steane
# NOT FOUND Andrew_MacFie
# NOT FOUND Andrew_Neitzke
# NOT FOUND Andrew_Pitts
# SUGG Andrew_Putman found: Q52004698
# SUGG Andrew_Ranicki found: Q506805
# NOT FOUND Andrew_Salch
# NOT FOUND Andrew_Snowden
# NOT FOUND Andrew_Stacey
# SUGG Andrew_Strominger found: Q507732
# SUGG Andrew_Sutherland found: Q4758676
# SUGG Andrew_Swan found: Q4758678
# SUGG Andrew_Wiles found: Q184433
# SUGG Andrews–Curtis_conjecture found: Q2409999
# SUGG Andrey_Kolmogorov found: Q153224
# NOT FOUND Andrey_Lazarev
# SUGG Andrey_Markov found: Q176659
# NOT FOUND Andrey_Markov_Jr
# SUGG Andrey_Morozov found: Q4755877
# SUGG Andrey_Tikhonov found: Q502637
# NOT FOUND Andrey_Todorov
# SUGG Andries_E._Brouwer found: Q2846875
# NOT FOUND AndriusKulikauskas
# SUGG Andrzej_Buras found: Q24206092
# NOT FOUND Andrzej_Derdzinski
# NOT FOUND Andrzej_Filinski
# NOT FOUND Andrzej_Kozlowski
# NOT FOUND Andrzej_M._Borzyszkowski
# NOT FOUND Andrzej_Tarlecki
# NOT FOUND András_Csépai
# SUGG András_Kovács found: Q848276
# SUGG André_Haefliger found: Q118872
# NOT FOUND André_Henriques
# NOT FOUND André_Hirschowitz
# SUGG André_Joyal found: Q2815652
# NOT FOUND André_Juan_Ferreira-Martins
# SUGG André_Lichnerowicz found: Q520942
# NOT FOUND André_Miemiec
# SUGG André_Neveu found: Q325967
# SUGG André_Néron found: Q522105
# SUGG André_Petermann found: Q18132175
# SUGG André_Weil found: Q323232
# SUGG André-Quillen_homology found: Q4760300
# NOT FOUND Andrés_Villaveces
# NOT FOUND Andy_Tonks
# NOT FOUND Angel_Toledo
# NOT FOUND Angelo_Vistoli
# SUGG Angle found: Q11352
# SUGG Angular_momentum found: Q161254
# SUGG Angular_velocity found: Q161635
# NOT FOUND Angélica_M._Osorno
# NOT FOUND Angélica_Osorno
# NOT FOUND Anibal_M._Medina-Mardones
# NOT FOUND Aniceto_Murillo
# SUGG Anirban_Basu found: Q47545731
# NOT FOUND Anisomorphism
# NOT FOUND ANITA_experiment
# NOT FOUND Anna_Beliakova
# SUGG Anna_Ceresole found: Q56948614
# NOT FOUND Anna_Labella
# NOT FOUND Anna_Marie_Bohmann
# SUGG Anne_Broadbent found: Q52698223
# NOT FOUND Anne_Marie_Svane
# SUGG Anne_Sjerp_Troelstra found: Q565846
# SUGG Annette_Huber found: Q109297
# SUGGCAT Annulus_(mathematics) found: Q45926
# SUGG Anodyne_morphism found: Q1941896
# NOT FOUND AnodyneHoward
# SUGG Anomalous_diffusion found: Q567544
# SUGG Anomalous_magnetic_moment found: Q771367
# SUGG Anomaly_cancellation found: Q567560
# NOT FOUND Anonymous_Hero_>_history
# NOT FOUND Anonymous_User
# NOT FOUND Another_page_>_history
# NOT FOUND Ansten_Klev
# NOT FOUND Antecedent
# NOT FOUND Anthony_Ashmore
# NOT FOUND Anthony_Bahri
# NOT FOUND Anthony_Bak
# SUGG Anthony_Blanc found: Q4775434
# NOT FOUND Anthony_Bordg
# NOT FOUND Anthony_Durity
# NOT FOUND Anthony_Elmendorf
# NOT FOUND Anthony_Houppe
# SUGG Anthony_Knapp found: Q573490
# NOT FOUND Anthony_Licata
# SUGG Anthony_Morse found: Q4773149
# SUGG Anthony_P._Morse found: Q4773149
# NOT FOUND Anthony_Scholl
# NOT FOUND Anthony_Sudbery
# NOT FOUND Anthony_Voutas
# SUGG Anthony_Zee found: Q574181
# NOT FOUND Anti_D-brane
# NOT FOUND Anti_de_Sitter_group
# NOT FOUND Anti_de_Sitter_space_>_history
# NOT FOUND Anti_de_Sitter_spacetime
# NOT FOUND Anti-commutator
# NOT FOUND Anti-cyclotomic_field
# NOT FOUND Anti-dual_linear_space
# NOT FOUND Anti-ghost_field
# NOT FOUND Anti-ideal_predicate
# NOT FOUND Anti-reduced_type
# NOT FOUND Anti-Yetter-Drinfeld_module
# NOT FOUND Antibracket
# SUGG Antichain found: Q431937
# NOT FOUND Anticommutative_graded_codifferential_category
# NOT FOUND Antifield
# SUGG Antihomomorphism found: Q575857
# SUGG Antilinear_map found: Q2719767
# SUGG Antiparticle found: Q182717
# SUGGCAT Antipode_(mathematics) found: Q505356
# NOT FOUND Antisubalgebra
# SUGG Antisymmetric_relation found: Q583760
# SUGG Antiunitary_operator found: Q4775348
# NOT FOUND Antoine_Allioux
# NOT FOUND Antoine_Van_Proeyen
# NOT FOUND Anton_A._Burkov
# SUGG Anton_Alekseev found: Q4775636
# NOT FOUND Anton_Deitmar
# NOT FOUND Anton_Geraschenko
# NOT FOUND Anton_Gerasimov
# NOT FOUND Anton_Hilado
# SUGG Anton_Kapustin found: Q4775834
# NOT FOUND Anton_Petrunin
# NOT FOUND Anton_Rebhan
# NOT FOUND Anton_Setzer
# NOT FOUND Anton_Suschkewitsch
# NOT FOUND Anton_Zabrodin
# SUGG Anton_Zeilinger found: Q78610
# NOT FOUND Anton_Zeitlin
# SUGG Antonella_Grassi found: Q42760513
# NOT FOUND Antoni_Kosinski
# NOT FOUND Antonin_Delpeuch
# NOT FOUND Antonio_Alarcón
# NOT FOUND Antonio_Cegarra
# NOT FOUND Antonio_Gallerati
# NOT FOUND Antonio_Gómez-Tato
# NOT FOUND Antonio_N._Bernal
# NOT FOUND Antonio_Pich
# NOT FOUND Antonio_R._Garzón
# SUGG Antony_Wassermann found: Q56248375
# NOT FOUND Antti_J._Niemi
# SUGG Antti_Kupiainen found: Q609702
# NOT FOUND Anyonic_braiding_in_momentum_space_--_references
# NOT FOUND Anyonic_topological_order_via_braided_fusion_categories_--_references
# NOT FOUND Anyons_in_the_quantum_Hall_effect_--_references
# NOT FOUND Anyons_in_topological_superconductors_--_references
# SUGG Apartness_relation found: Q4779193
# NOT FOUND Apartness_space
# NOT FOUND Apartness-open_predicate
# NOT FOUND Application_of_holographic_QCD_to_B-meson_physics_--_references
# NOT FOUND Application_of_topology
# NOT FOUND Applications_of_(higher)_category_theory
# NOT FOUND Applications_of_double_category_theory
# SUGG Applicative_functor found: Q25104369
# NOT FOUND Applied_category_theory
# SUGG Applied_mathematics found: Q33521
# NOT FOUND Applied_topology
# SUGG Approach_space found: Q4781718
# NOT FOUND Approximate_fibration
# NOT FOUND Approximate_integral_domain
# SUGG Approximation found: Q27058
# SUGG Approximation_of_the_identity found: Q621743
# NOT FOUND AQFT
# NOT FOUND AQFT_and_operator_algebra_contents
# NOT FOUND AQFT_on_curved_spacetimes
# SUGG Arakelov_geometry found: Q4783822
# NOT FOUND Araminta_Amabel
# NOT FOUND Aravind_Asok
# NOT FOUND Arc_space
# NOT FOUND Arccos
# NOT FOUND Archana_Morye
# NOT FOUND Archetypal_example
# SUGG Archibald_Richardson found: Q55543543
# NOT FOUND Archimedean_difference_protoring
# SUGG Archimedean_field found: Q634579
# SUGG Archimedean_group found: Q4786884
# NOT FOUND Archimedean_ordered_Artinian_local_ring
# SUGG Archimedean_ordered_field found: Q634579
# NOT FOUND Archimedean_ordered_integral_domain
# NOT FOUND Archimedean_ordered_local_integral_domain
# NOT FOUND Archimedean_ordered_local_ring
# NOT FOUND Archimedean_ordered_reduced_local_ring
# SUGG Archimedean_property found: Q634579
# NOT FOUND Archimedean_protoring
# NOT FOUND Archimedean_valued_field
# SUGG Archimedes found: Q8739
# NOT FOUND Archive_for_Mathematical_Sciences_&_Philosophy
# NOT FOUND Archive_of_Formal_Proofs
# SUGG Arcsin found: Q674533
# SUGG Arctangent found: Q674533
# SUGGCAT Area_(mathematics) found: Q11500
# NOT FOUND Area_enclosed_by_a_circle
# SUGG Areal_velocity found: Q2266743
# NOT FOUND Arend
# SUGG Arend_Heyting found: Q641771
# SUGG Arens-Fort_space found: Q642105
# SUGG Arf_invariant found: Q4789139
# NOT FOUND Arf-Kervaire_invariant_problem
# SUGG Argument_shift_method found: Q4789751
# NOT FOUND Ari_M._Turner
# SUGG Aristotle found: Q868
# SUGG Arithmetic found: Q11205
# NOT FOUND Arithmetic_and_noncommutative_geometry
# NOT FOUND Arithmetic_Chern-Simons_theory
# SUGG Arithmetic_Chow_group found: Q4783822
# NOT FOUND Arithmetic_cohesion_--_table
# NOT FOUND Arithmetic_cryptography
# NOT FOUND Arithmetic_curve
# NOT FOUND Arithmetic_D-module
# NOT FOUND Arithmetic_differential_geometry
# NOT FOUND Arithmetic_gauge_theory
# SUGG Arithmetic_genus found: Q4791125
# NOT FOUND Arithmetic_geometry
# NOT FOUND Arithmetic_geometry_-_contents
# NOT FOUND Arithmetic_geometry_--_contents
# NOT FOUND Arithmetic_jet_space
# NOT FOUND Arithmetic_pretopos
# SUGG Arithmetic_Riemann-Roch_theorem found: Q4783822
# SUGG Arithmetic_scheme found: Q4783822
# SUGG Arithmetic_topology found: Q4791133
# SUGG Arithmetic_variety found: Q4791136
# SUGG Arithmetic_zeta_function found: Q4791135
# SUGG Arity found: Q1315869
# NOT FOUND Arity_class
# NOT FOUND Arity_space
# NOT FOUND Arjan_Keurentjes
# NOT FOUND Arkaday_Tseytlin
# NOT FOUND Arkady_Berenstein
# NOT FOUND Arkady_Tseytlin
# SUGG Arkady_Vainshtein found: Q672559
# NOT FOUND Arkady_Vaintrob
# SUGG Armand_Borel found: Q123474
# NOT FOUND Armin_Frei
# SUGG Arnaud_Beauville found: Q691176
# NOT FOUND Arnaud_Spiwack
# NOT FOUND Arnav_Tripathy
# NOT FOUND Arne_Ostvaer
# NOT FOUND Arne_Strøm
# SUGG Arnold_conjecture found: Q1049064
# NOT FOUND Arnold_Neumaier
# SUGG Arnold_Nordsieck found: Q695856
# SUGG Arnold_Shapiro found: Q4795252
# SUGG Arnold_Sommerfeld found: Q77078
# NOT FOUND Arnold-Kuiper-Massey_theorem
# NOT FOUND Aron_C._Wall
# NOT FOUND Aron_J._Beekman
# NOT FOUND Arpon_Raksit
# SUGG Arrangement_of_hyperplanes found: Q4795851
# SUGGCAT Arrow_(category_theory) found: Q1948412
# NOT FOUND Arrow_(in_computer_science)
# NOT FOUND Arrow_(∞,1)-category
# NOT FOUND Arrow_(∞,1)-topos
# SUGG Arrow_category found: Q1780005
# NOT FOUND Arrow_structure
# NOT FOUND Arsmath
# SUGG Arthur_Bartels found: Q52985678
# SUGG Arthur_Besse found: Q2865000
# SUGG Arthur_Cayley found: Q159430
# SUGG Arthur_Eddington found: Q215022
# NOT FOUND Arthur_Greenspoon
# NOT FOUND Arthur_Gretton
# SUGG Arthur_H._Stone found: Q3709232
# SUGG Arthur_Jaffe found: Q370094
# NOT FOUND Arthur_L._Stone
# SUGG Arthur_Ogus found: Q18631929
# NOT FOUND Arthur_Parzygnat
# SUGG Arthur_Prior found: Q250020
# NOT FOUND Arthur_Sale
# SUGG Arthur_Sard found: Q711331
# SUGG Arthur_Schopenhauer found: Q38193
# NOT FOUND Arthur_Wasserman
# SUGG Arthur_Wightman found: Q712042
# SUGG Arthur-Selberg_trace_formula found: Q4800826
# NOT FOUND Artin_gluing
# SUGG Artin_L-function found: Q2993300
# SUGG Artin_reciprocity_law found: Q713069
# NOT FOUND Artin_representability_theorem
# SUGG Artin_stack found: Q7595945
# NOT FOUND Artin-Lam_induction_exponent
# NOT FOUND Artin-Lurie_representability_theorem
# NOT FOUND Artin-Mazur_codiagonal
# NOT FOUND Artin-Mazur_formal_group
# NOT FOUND Artin-Schreier_sequence
# SUGG Artin-Tate_lemma found: Q19595940
# NOT FOUND Artinian_bimodule
# SUGG Artinian_local_ring found: Q713084
# SUGG Artinian_ring found: Q713084
# SUGG Artur_Ekert found: Q714360
# NOT FOUND Arturo_Prat-Waldron
# NOT FOUND Arun_Debray
# NOT FOUND Arun_Kumar_Pati
# NOT FOUND Arun_Ram
# NOT FOUND Arunas_Liulevicius
# SUGG Arvind_Rajaraman found: Q4802501
# SUGG Ascending_chain_condition found: Q2528476
# NOT FOUND Asgar_Jamneshan
# SUGG Ash_Asudeh found: Q28839543
# SUGG Asher_Peres found: Q340101
# NOT FOUND Ashkbiz_Danehkar
# SUGG Ashok_Das found: Q4805729
# SUGG Ashoke_Sen found: Q726244
# SUGG Ashvin_Vishwanath found: Q19609632
# NOT FOUND Ashwin_S._Pande
# NOT FOUND Asif_Equbal
# NOT FOUND Assaf_Libman
# SUGG Assembly_map found: Q4808684
# NOT FOUND ASSet
# NOT FOUND Assia_Mahboubi
# NOT FOUND Assignment_>_history
# SUGG Assignment_operator found: Q231158
# SUGG Associahedron found: Q4809117
# NOT FOUND Associahedron_>_K4
# SUGG Associated_bundle found: Q427018
# NOT FOUND Associated_graded_object
# SUGG Associated_graded_ring found: Q17097755
# NOT FOUND Associated_graded_vector_space
# NOT FOUND Associated_infinity-bundle
# NOT FOUND Associative_3-form
# NOT FOUND Associative_dialgebra
# NOT FOUND Associative_H-space
# NOT FOUND Associative_magma
# NOT FOUND Associative_n-category
# SUGG Associative_operad found: Q842072
# NOT FOUND Associative_quasigroup
# NOT FOUND Associative_quasigroupoid
# NOT FOUND Associative_ring_spectrum
# NOT FOUND Associative_submanifold
# NOT FOUND Associative_unital_algebra
# NOT FOUND Associative_Yang-Baxter_equation
# SUGG Associativity found: Q177251
# SUGG Associator found: Q2405805
# NOT FOUND Astra_Kolomatskaia
# SUGG Astronomy found: Q333
# SUGG Astérisque found: Q4811832
# SUGG Asymmetric_relation found: Q2298831
# NOT FOUND Asymptotic_boundary
# NOT FOUND Asymptotic_C-star-homomorphism
# SUGG Asymptotic_dimension found: Q28456166
# SUGG Asymptotic_expansion found: Q752726
# SUGG Asymptotic_freedom found: Q752732
# NOT FOUND Asymptotic_isometry
# SUGG Asymptotic_notation found: Q269878
# NOT FOUND Asymptotic_representation_theory
# SUGG Asymptotic_safety found: Q17004315
# ...
# SUGG Wedge_sum found: Q1781358
# NOT FOUND Wedge_sum_type
# NOT FOUND Wei_Cui
# SUGG Wei-Liang_Chow found: Q2554748
# SUGG Weierstrass_elliptic_function found: Q2343600
# SUGG Weierstrass_preparation_theorem found: Q3527219
# NOT FOUND Weierstrass_sigma-function
# SUGGCAT Weight_(mathematics) found: Q856577
# NOT FOUND Weight_(in_representation_theory)
# SUGG Weight_filtration found: Q4444341
# NOT FOUND Weight_system
# NOT FOUND Weight_systems_are_cohomology_of_knot_graph_complex
# NOT FOUND Weight_systems_are_cohomology_of_loop_space_of_configuration_space
# NOT FOUND Weight_systems_are_the_associated_graded_objects_of_Vassiliev_invariants
# NOT FOUND Weight_systems_on_chord_diagrams_in_physics
# NOT FOUND Weighted_colimit
# SUGG Weighted_graph found: Q166507
# NOT FOUND Weighted_homotopy_theory
# NOT FOUND Weighted_limit
# SUGG Weil_algebra found: Q7980183
# NOT FOUND Weil_algebra_abstractly_--_table
# SUGG Weil_cohomology_theory found: Q7980184
# SUGG Weil_conjecture_on_Tamagawa_numbers found: Q7980185
# SUGG Weil_conjectures found: Q1479613
# SUGG Weil_divisor found: Q909669
# SUGG Weil_group found: Q17104667
# SUGG Weil_reciprocity_law found: Q7980189
# NOT FOUND Weil_uniformization_theorem
# SUGG Weil_zeta_function found: Q2372257
# SUGG Weil-Deligne_representation found: Q3427418
# SUGG Weil-Petersson_metric found: Q7980206
# NOT FOUND Weil-étale_site
# NOT FOUND Weil-étale_topology_for_arithmetic_schemes
# NOT FOUND Weimin_Chen
# NOT FOUND Weinstein_symplectic_category
# NOT FOUND Weinstein,_the_geometry_of_Lubin-Tate_spaces
# NOT FOUND Weiping_Zhang
# NOT FOUND Weiss_topology
# SUGG Weitzenböck_connection found: Q4454070
# NOT FOUND Weizhe_Zheng
# NOT FOUND Well_group
# NOT FOUND Well-connected_space
# NOT FOUND Well-founded_coalgebra
# SUGG Well-founded_relation found: Q338021
# NOT FOUND Well-generated_triangulated_category
# SUGG Well-order found: Q659746
# SUGG Well-ordering_theorem found: Q1457052
# NOT FOUND Well-pointed_endofunctor
# NOT FOUND Well-pointed_topical_dagger_2-poset
# NOT FOUND Well-pointed_topological_space
# NOT FOUND Well-pointed_topos
# NOT FOUND Well-powered_abelian_category
# NOT FOUND Well-powered_category
# SUGG Well-quasi-order found: Q2894153
# SUGG Wen-Tsun_Wu found: Q926125
# NOT FOUND Wendong_Liang
# NOT FOUND Wendy_Lowen
# NOT FOUND Werner_Burau
# NOT FOUND Werner_Greub
# SUGG Werner_Heisenberg found: Q40904
# SUGG Werner_Nahm found: Q1515185
# NOT FOUND Werner_Porod
# SUGG Wess-Zumino-Witten_model found: Q850946
# SUGG Weyl_algebra found: Q1069378
# NOT FOUND Weyl_bundle
# SUGG Weyl_character_formula found: Q7990328
# NOT FOUND Weyl_functional_calculus
# SUGG Weyl_group found: Q768074
# NOT FOUND Weyl_n-algebra
# NOT FOUND Weyl_relation
# NOT FOUND Weyl_ring
# SUGG Weyl_semimetal found: Q21193667
# SUGG Weyl_spinor found: Q2566340
# SUGG Weyl_tensor found: Q869108
# NOT FOUND What_is_an_elliptic_object?
# NOT FOUND What_to_contribute
# SUGG Wheel found: Q446
# NOT FOUND Wheeled_graph
# NOT FOUND Wheeledgraph_>_corolla1
# NOT FOUND Wheeler_superspace
# NOT FOUND Wheels_theorem
# NOT FOUND Whiskering
# NOT FOUND Whisky_club
# SUGG White_noise found: Q381287
# NOT FOUND Whitehead
# NOT FOUND Whitehead_integral_formula
# SUGG Whitehead_link found: Q2588098
# NOT FOUND Whitehead_link_-_SVG
# NOT FOUND Whitehead_principle_of_nonabelian_cohomology
# SUGG Whitehead_product found: Q7996042
# SUGG Whitehead_theorem found: Q3527185
# SUGG Whitehead_torsion found: Q7996043
# NOT FOUND Whitehead_tower
# NOT FOUND Whitehead_tower_in_an_(infinity,1)-topos
# SUGG Whitney_embedding_theorem found: Q1306095
# SUGG Whitney_extension_theorem found: Q7996766
# SUGG Whittaker_function found: Q3754618
# NOT FOUND Why_(infinity,1)-categories?
# NOT FOUND WhyNotZoidgebra?
# NOT FOUND Wick_algebra
# NOT FOUND Wick_algebra_--_table
# SUGG Wick_rotation found: Q1807879
# NOT FOUND Wick's_lemma
# NOT FOUND Wide_pullback
# NOT FOUND Wide_subcategory
# NOT FOUND Wiebe_van_der_Hoek
# SUGG Wiener_measure found: Q1056809
# NOT FOUND Wiener-Hopf_decomposition
# NOT FOUND Wieslaw_Pawlowski
# SUGG Wightman_axioms found: Q2874804
# NOT FOUND Wigner_9j_symbol
# SUGG Wigner_classification found: Q12609547
# NOT FOUND Wigner_function
# SUGG Wigner_theorem found: Q1135224
# NOT FOUND Wild_category
# NOT FOUND Wiles'_proof_of_Fermat's_last_theorem
# SUGG Wilfrid_Hodges found: Q451634
# SUGG Wilhelm_Ackermann found: Q61037
# SUGG Wilhelm_Killing found: Q77304
# SUGG Wilhelm_Magnus found: Q73012
# NOT FOUND Wilhemus_A._J._Luxemburg
# SUGG Willard_Miller found: Q8003462
# SUGG Willard_Quine found: Q214969
# SUGG Willem_van_Est found: Q960296
# NOT FOUND William_Abram
# SUGG William_Arveson found: Q711281
# SUGG William_Barlow found: Q527571
# SUGG William_Browder found: Q8006002
# SUGG William_Burnside found: Q442983
# SUGG William_Clifford found: Q528295
# SUGG William_Crawley-Boevey found: Q1515459
# SUGG William_Detmold found: Q8007792
# SUGG William_Dunbar found: Q647150
# SUGG William_Dwyer found: Q8008166
# NOT FOUND William_F._Sawin
# SUGG William_Fulton found: Q8009479
# NOT FOUND William_G._Dwyer_>_history
# SUGG William_Hodge found: Q16029330
# SUGG William_Howard found: Q363259
# NOT FOUND William_J._Munro
# NOT FOUND William_K._Wootters
# NOT FOUND William_Keigher
# SUGG William_Kinney found: Q15638670
# NOT FOUND William_Kirwin
# NOT FOUND William_Kronholm
# SUGG William_Lawvere found: Q290932
# NOT FOUND William_Linch_III
# NOT FOUND William_M._Boothby
# SUGG William_Massey found: Q923806
# SUGG William_Messing found: Q2579982
# SUGG William_Mycroft found: Q16060067
# SUGG William_Rowan_Hamilton found: Q11887
# SUGG William_S._Massey found: Q8017979
# SUGG William_Stein found: Q3568967
# SUGG William_T._Tutte found: Q1391861
# SUGG William_Tait found: Q8019157
# SUGG William_Thurston found: Q333927
# NOT FOUND William_Wooters
# SUGG Willis_Lamb found: Q186497
# SUGG Willy_Fischler found: Q2169476
# NOT FOUND Wilson_line_>_history
# SUGG Wilson_loop found: Q206552
# NOT FOUND Wilson_surface
# NOT FOUND Wim_Hordijk
# NOT FOUND Wim_Ruitenberg
# NOT FOUND Wim_van_Dam
# SUGG Winding_number found: Q576728
# NOT FOUND Winter_2016-2017_seminar_on_higher_structures
# NOT FOUND Winter_2017-2018_seminar_on_higher_structures_(Higher_Lie_Groupoids)
# NOT FOUND Wirthmüller_context
# NOT FOUND WISC
# SUGG Witold_Hurewicz found: Q1930684
# SUGG Witt_cohomology found: Q30704540
# NOT FOUND Witt_ring
# NOT FOUND Witt_ring_of_equivalence_classes_of_bilinear_forms
# NOT FOUND Witt_vectors_>_history
# NOT FOUND Witt-Burnside_functor
# SUGG Witten_conjecture found: Q8028565
# SUGG Witten_genus found: Q5533833
# SUGG Witten_index found: Q8028562
# NOT FOUND Witten's_Dark_Fantasy
# SUGG WKB_method found: Q907306
# NOT FOUND Wlodzimierz_M._Tulczyjew
# NOT FOUND Wojciech_Chachólski
# NOT FOUND Wojciech_De_Roeck
# SUGG Wojciech_Zurek found: Q684933
# SUGG Wolf_space found: Q7269563
# NOT FOUND Wolfgang_Altmannshofer
# NOT FOUND Wolfgang_Dür
# NOT FOUND Wolfgang_L._Reiter
# NOT FOUND Wolfgang_Lerche
# NOT FOUND Wolfgang_Lueck
# SUGG Wolfgang_Pauli found: Q65989
# NOT FOUND Wolfgang_Polak
# SUGG Wolfgang_Rindler found: Q954665
# NOT FOUND Wolfgang_Rump
# NOT FOUND Wolfgang_Soergel
# NOT FOUND Wolfgang_Steinicke
# NOT FOUND Wolfgang_Ziller
# SUGG Wolfhart_Zimmermann found: Q75239
# NOT FOUND Wolfram_Schwabhäuser
# NOT FOUND Wolfram_Weise
# SUGG Wonderful_compactification found: Q8031858
# SUGGCAT Word_(mathematics) found: Q10944557
# NOT FOUND World_sheets_for_world_sheets
# NOT FOUND Worldline_formalism
# NOT FOUND Worldsheet_instanton
# NOT FOUND Worldsheet_parity_operator
# SUGG Worldvolume found: Q385601
# NOT FOUND Worldvolume-target_supersymmetry_of_brane_sigma-models
# SUGG Wormhole found: Q7544
# NOT FOUND Wout_Merbis
# NOT FOUND Wouter_Swierstra
# NOT FOUND Wrapped_brane
# SUGG Wreath found: Q1201922
# SUGG Wreath_product found: Q1786640
# NOT FOUND Wreath_product_of_groups
# SUGG Writhe found: Q778947
# NOT FOUND Writing_in_the_nLab
# SUGG Wronskian found: Q124743
# SUGG Wu_class found: Q1293273
# NOT FOUND Wu_manifold
# NOT FOUND WZW_term_of_QCD_chiral_perturbation_theory_--_references
# NOT FOUND WZW-type_superstring_field_theory
# NOT FOUND Xavier_Bekaert
# NOT FOUND Xena_project
# SUGG Xenia_de_la_Ossa found: Q53673448
# NOT FOUND Xi_Dong
# SUGG Xi_Yin found: Q27964431
# NOT FOUND Xia_Gu
# NOT FOUND Xianzhe_Dai
# SUGG Xiao-Gang_Wen found: Q2514375
# NOT FOUND Xiao-Song_Lin
# NOT FOUND Xie_Chen
# SUGG Xin_Wang found: Q7967694
# SUGG Xinwen_Zhu found: Q27967789
# NOT FOUND XTT
# NOT FOUND Xyz
# SUGG XYZ_particle found: Q30672672
# NOT FOUND Y-system
# NOT FOUND Ya-Wen_Sun
# NOT FOUND Yael_Fregier
# SUGG Yael_Karshon found: Q30336000
# SUGG Yakir_Aharonov found: Q721892
# SUGG Yakov_Eliashberg found: Q1399503
# NOT FOUND Yakov_Itin
# NOT FOUND Yakov_Kremnitzer
# NOT FOUND Yakov_Shnir
# SUGG Yan_Liu found: Q410023
# SUGG Yan_Soibelman found: Q8048171
# SUGG Yan_Zhang found: Q8070378
# NOT FOUND Yang_monopole
# SUGG Yang_Qiu found: Q8048443
# NOT FOUND Yang_Yang
# SUGG Yang_Zhang found: Q8070380
# SUGG Yang-Baxter_equation found: Q4476530
# NOT FOUND Yang-Baxter_equations_--_contents
# NOT FOUND Yang-Hui_He
# SUGG Yang-Mills_equation found: Q1192873
# SUGG Yang-Mills_field found: Q1192873
# SUGG Yang-Mills_instanton found: Q1192916
# NOT FOUND Yang-Mills_instanton_Floer_homology
# NOT FOUND Yang-Mills_monopoles_as_rational_maps_--_references
# SUGG Yang-Mills_theory found: Q1192873
# SUGG Yangian found: Q8048582
# SUGG Yannick_Bertrand found: Q710815
# SUGG Yaron found: Q56243706
# SUGG Yaron_Oz found: Q21616102
# NOT FOUND Yasuhiko_Yamada
# NOT FOUND Yasunori_Lee
# NOT FOUND Yasuyuki_Kawahigashi
# NOT FOUND Yde_Venema
# SUGG Year found: Q577
# NOT FOUND Yehonatan_Sella
# NOT FOUND Yemon_Choi
# NOT FOUND Yetter_model
# SUGG Yetter-Drinfeld_module found: Q8053054
# NOT FOUND Yevsey_Nisnevich
# SUGG Yi_Zhang found: Q197318
# NOT FOUND Yi-Hong_Chen
# NOT FOUND Yi-Nan_Wang
# NOT FOUND Yi-Zhi_Huang
# NOT FOUND Yiannis_Sakellaridis
# NOT FOUND Yiannis_Vlassopoulos
# NOT FOUND Yihua_Liu
# NOT FOUND Yimin_Yang
# NOT FOUND Yitzhak_Frishman
# NOT FOUND Yoichi_Ando
# NOT FOUND Yoichi_Kazama
# SUGG Yoichiro_Nambu found: Q188120
# NOT FOUND Yolanda_Lozano
# NOT FOUND Yonatan_Harpaz
# SUGG Yoneda_embedding found: Q320577
# SUGG Yoneda_extension found: Q7241077
# SUGG Yoneda_lemma found: Q320577
# NOT FOUND Yoneda_lemma_-_contents
# NOT FOUND Yoneda_lemma_for_(infinity,1)-categories
# NOT FOUND Yoneda_lemma_for_bicategories
# NOT FOUND Yoneda_lemma_for_higher_categories
# NOT FOUND Yoneda_lemma_for_tricategories
# NOT FOUND Yoneda_reduction
# NOT FOUND Yoneda_structure
# NOT FOUND Yong-Baek_Kim
# NOT FOUND Yong-Geun_Oh
# NOT FOUND Yong-Shi_Wu
# NOT FOUND Yongbin_Ruan
# SUGG Yoram_Moses found: Q2897783
# NOT FOUND Yoseph_Ayoub_>_history
# NOT FOUND Yoshiaki_Tanii
# NOT FOUND Yoshiki_Kinoshita
# NOT FOUND Yoshinori_Matsuo
# NOT FOUND Yosida_duality
# NOT FOUND You_Qi
# NOT FOUND Younesse_Kaddar
# SUGG Young_diagram found: Q2166280
# SUGG Young_measure found: Q8058552
# NOT FOUND Young_subgroup
# NOT FOUND Young's_inequality
# SUGG Young–Fibonacci_lattice found: Q8058685
# NOT FOUND Yu_Qiu
# NOT FOUND Yu-tin_Huang
# NOT FOUND Yuan_Feng
# NOT FOUND Yufei_Zhao
# NOT FOUND Yuhma_Asano
# NOT FOUND Yuho_Sakatani
# SUGG Yuji_Tachikawa found: Q11597939
# NOT FOUND Yuji_Terashima
# SUGG Yukawa_coupling found: Q31387
# NOT FOUND Yuki_Maehara
# SUGG Yuli_Rudyak found: Q8060923
# NOT FOUND Yunlong_Jiao
# NOT FOUND Yunze_Lu
# NOT FOUND Yuri_Berest
# SUGG Yuri_Burago found: Q710985
# SUGG Yuri_Golfand found: Q1713865
# SUGG Yuri_Gurevich found: Q8061506
# NOT FOUND Yuri_Makeenko
# SUGG Yuri_Manin found: Q65196
# SUGG Yuri_Matiyasevich found: Q707119
# NOT FOUND Yuri_N._Obukhov
# NOT FOUND Yuri_Tschinkel
# NOT FOUND Yuri_Ximenes_Martins
# NOT FOUND Yurii_Antonovich_Simonov
# NOT FOUND Yuta_Kusakabe
# NOT FOUND Yutaka_Hosotani
# SUGG Yutaka_Taniyama found: Q351405
# NOT FOUND Yuval_Grossman
# SUGG Yuval_Ne'eman found: Q471965
# NOT FOUND Yuval_Roichman
# NOT FOUND Yuxi_Liu
# NOT FOUND Yves_Andre
# NOT FOUND Yves_Diers
# NOT FOUND Yves_Félix
# NOT FOUND Yves_Guiraud
# NOT FOUND Yves_Hellegouarch
# NOT FOUND Yves_Lafont
# SUGG Yves_Laszlo found: Q268830
# SUGG Yvette_Kosmann-Schwarzbach found: Q6506935
# SUGG Yvonne_Choquet-Bruhat found: Q461112
# SUGG Z found: Q9751
# NOT FOUND Z'-boson
# NOT FOUND Z+_ring
# NOT FOUND Z-infinity-module
# NOT FOUND Z-theory
# NOT FOUND Zach_Goldthorpe
# NOT FOUND Zachary_Murray
# NOT FOUND Zachery_Lindsey
# SUGG Zamolodchikov_equation found: Q6422663
# SUGG Zariski_geometry found: Q8066797
# NOT FOUND Zariski_site
# SUGG Zariski_topology found: Q147978
# NOT FOUND Zbigniew_Fiedorowicz
# NOT FOUND Zbigniew_Semadeni
# SUGG Zdenek_Dolezal found: Q168970
# NOT FOUND Zekeriya_arvasi
# NOT FOUND Zena_M._Ariola
# NOT FOUND Zeno
# NOT FOUND Zeno's_paradox_of_motion
# SUGG Zentralblatt_MATH found: Q190269
# NOT FOUND Zeph_Landau
# SUGGCAT Zero_(mathematics) found: Q204
# NOT FOUND Zero_bundle
# SUGG Zero_function found: Q204
# SUGG Zero_ideal found: Q1468740
# NOT FOUND Zero_locus
# SUGG Zero_morphism found: Q2905069
# SUGG Zero_object found: Q529752
# SUGG Zero_section found: Q658429
# NOT FOUND Zero_spectrum
# SUGG Zero_vector found: Q1468740
# SUGG Zero-divisor found: Q828111
# NOT FOUND Zero-one_law
# NOT FOUND Zero-section_into_Thom_space_of_universal_line_bundle_is_weak_equivalence
# NOT FOUND Zero-set_structure
# SUGG Zeta_function found: Q196822
# NOT FOUND Zeta_function_of_a_dynamical_system
# NOT FOUND Zeta_function_of_a_Riemann_surface
# NOT FOUND Zeta_function_of_an_elliptic_differential_operator
# SUGG Zeta_function_regularization found: Q1048264
# NOT FOUND Zeta_polynomial
# NOT FOUND Zeta-functions_and_eta-functions_and_theta-functions_and_L-functions_--_table
# NOT FOUND ZFA
# SUGG ZFC found: Q191849
# NOT FOUND Zhaohui_Luo
# SUGG Zhen_Huan found: Q11070218
# NOT FOUND Zhen_Lin_>_history
# NOT FOUND Zhen_Lin_Low
# NOT FOUND Zhenbin_Yang
# SUGG Zheng_Yin found: Q8070750
# NOT FOUND Zheng-Cheng_Gu
# NOT FOUND Zheng-Xin_Liu
# NOT FOUND Zhenghan_Wang
# NOT FOUND Zhi_Lu
# NOT FOUND Zhih-Ahn_Jia
# NOT FOUND Zhiqin_Lu
# SUGG Zhiwei_Yun found: Q8462706
# NOT FOUND Zhouli_Xu
# NOT FOUND Zhuan_Li
# NOT FOUND Zhuo_Chen
# NOT FOUND Zi-zhi_Wang
# SUGG Ziegler_spectrum found: Q48996495
# SUGG Zigzag found: Q198438
# NOT FOUND Zigzag_category
# NOT FOUND Zigzag_identity_1_-_SVG
# NOT FOUND Zigzag_identity_1_implies_2_-_SVG
# NOT FOUND Zigzag_of_real_numbers_-_SVG
# NOT FOUND Zigzag_persistence_module
# SUGG Zinbiel_algebra found: Q2835946
# NOT FOUND Zinovy_Diskin
# NOT FOUND Ziv_Ran
# NOT FOUND Zoe_Wyatt
# NOT FOUND Zohar_Komargodski
# NOT FOUND Zoltán_Zimborás
# NOT FOUND Zoran_Skoda_>_history
# NOT FOUND Zoran_Škoda
# SUGG Zorn's_lemma found: Q290810
# NOT FOUND Zuckerman_induction
# NOT FOUND Zuoqin_Wang
# NOT FOUND Zurab_Janelidze
# SUGG Zvi_Bern found: Q15855856
# NOT FOUND Zvonko_Iljazovic
# SUGG ZX-calculus found: Q5051814
# NOT FOUND |cocomplete_category_>_history
# NOT FOUND |identity_assigning_morphism_>_history
# NOT FOUND Álvaro_Pelayo
# NOT FOUND Ángel_Murcia
# NOT FOUND Ángel_Uranga
# NOT FOUND Æ_code
# SUGG Édouard_Goursat found: Q274322
# SUGG Élie_Cartan found: Q274639
# SUGG Émile_Borel found: Q154356
# NOT FOUND Éric_Goubault
# NOT FOUND Étale_(infinity,1)-site
# SUGG Étale_algebra found: Q17097882
# SUGG Étale_cohomology found: Q8078429
# NOT FOUND Étale_cover
# NOT FOUND Étale_geometric_morphism
# NOT FOUND Étale_groupoid
# NOT FOUND Étale_homotopy
# NOT FOUND Étale_infinity-groupoid
# SUGG Étale_map found: Q8078428
# NOT FOUND Étale_morphism_of_E-∞_rings
# SUGG Étale_site found: Q1062242
# SUGG Étale_space found: Q595298
# NOT FOUND Étale_theta_function
# SUGG Étale_topos found: Q17011044
# SUGG Étendue found: Q1370994
# SUGG Évariste_Galois found: Q7091
# SUGG Øystein_Ore found: Q329846
# SUGG Čech_cohomology found: Q1095535
# NOT FOUND Čech_cohomology_>_history
# NOT FOUND Čech_cover
# NOT FOUND Čech_descent
# NOT FOUND Čech_groupoid
# NOT FOUND Čech_homology
# NOT FOUND Čech_homotopy
# NOT FOUND Čech_methods
# NOT FOUND Čech_model_structure_on_simplicial_presheaves
# NOT FOUND Čech_model_structure_on_simplicial_sheaves
# NOT FOUND Čech_nerve
# NOT FOUND Čedomir_Crnković
# NOT FOUND Łoś_ultraproduct_theorem
# SUGG Łukasiewicz_logic found: Q8080919
# NOT FOUND Δ-ring
# NOT FOUND Κ-ary_exact_category
# NOT FOUND Κ-ary_site
# NOT FOUND Π-Kan_condition
# NOT FOUND Π-pretopos
# NOT FOUND ΠW-pretopos
# SUGG Σ-ideal found: Q7512218
# NOT FOUND Σ-meson
# NOT FOUND Ω-category_>_history
# NOT FOUND Ω-meson
# NOT FOUND Е._Б._Богомольный
# NOT FOUND Павел_Мнёв
# NOT FOUND שנה_טובה_>_history
# NOT FOUND ’t_Hooft_operator
# SUGG ℓ-adic_cohomology found: Q8078429
# NOT FOUND ∞-category_>_history
# NOT FOUND ∞-group_cohomology
# NOT FOUND ∞-group_∞-ring
# NOT FOUND ∞-groupoid_>_history
# NOT FOUND ∞-stack_>_history
# NOT FOUND ∞Grpd_>_history
# SUGG 道德經 found: Q134425

# %%
import csv

import urllib.parse

# Read the nlab_page_names_raw.txt file
with open('/Users/lucyhorowitz/Documents/GitHub/MathGloss/nlab/nlab_page_names_raw.txt', 'r') as file:
    nlab_page_names = [line.strip() for line in file.readlines()]

# Read the nlab_mappings.csv file
with open('/Users/lucyhorowitz/Documents/GitHub/MathGloss/nlab/nlab_mappings_dec_24.csv', mode='r') as file:
    reader = csv.reader(file)
    nlab_mappings = list(reader)

# Update the second column entries if a match is found
for i, row in enumerate(nlab_mappings[1:], start=1):  # Skip header row
    for page_name in nlab_page_names:
        encoded_page_name = urllib.parse.quote(page_name.replace(' ', '+'))
        if row[1].endswith(encoded_page_name):
            nlab_mappings[i][1] = f"[{page_name}](https://ncatlab.org/nlab/show/{encoded_page_name})"
            break

# Write the updated nlab_mappings.csv file
with open('nlab_mappings.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(nlab_mappings)

# %% [markdown]
# # planetmath

# %%
# Open the titles.csv file to read the titles
with open('/Users/lucyhorowitz/Documents/MathGloss/planetmath/titles.csv', mode='r') as file:
    reader = csv.reader(file)
    with open('planetmath_mappings.csv', mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Wikidata ID', 'PlanetMath Title'])
        for row in reader:

    # Open the planetmath_mappings.csv file to write the results
            suggestion = row[0].strip().replace(' ', '_')
            suggestion = suggestion[0].upper() + suggestion[1:]  # Capitalize only the first character
            found = False
            for cat in wikicats:
                suggestion_with_cat = suggestion + cat
                wikidata_id = map.title_to_id(suggestion_with_cat)
                if wikidata_id:
                    planetmath_link = row[1]  # Use the second column as the PlanetMath link
                    writer.writerow([f"[{wikidata_id}](https://www.wikidata.org/wiki/{wikidata_id})", f"[{row[0]}]({planetmath_link})"])
                    print(f"SUGGCAT {suggestion_with_cat} found: {wikidata_id}")
                    found = True
                    break
            if not found:
                wikidata_id = map.title_to_id(suggestion)
                if wikidata_id and not is_disambiguation_page(wikidata_id):
                    planetmath_link = row[1]  # Use the second column as the PlanetMath link
                    writer.writerow([f"[{wikidata_id}](https://www.wikidata.org/wiki/{wikidata_id})", f"[{row[0]}]({planetmath_link})"])
                    print(f"SUGG {suggestion} found: {wikidata_id}")
                    found = True
            if not found:
                print(f"NOT FOUND {row[0]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Open the titles.csv file to read the titles
#       2 with open('/Users/lucyhorowitz/Documents/MathGloss/planetmath/titles.csv', mode='r') as file:
# ----> 3     reader = csv.reader(file)
#       4     with open('planetmath_mappings.csv', mode='w', newline='') as file:
#       5         writer = csv.writer(file)
#
# NameError: name 'csv' is not defined
